# %%
import os
import sys

def adding_module_path():
    module_path = os.path.abspath(os.path.sep.join([".."]*5))

    if module_path not in sys.path:
        sys.path.append(module_path)

adding_module_path()

from src.config.run_prep import run_prep
from src.utils.log_juypter import add_experiment_jupyter_logger

run_prep()
add_experiment_jupyter_logger(os.getcwd())
# Out:
# Running preperation of packages
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# <_io.TextIOWrapper name='/home/usp/pro0255/diploma/jupyters/experiments/nn/no_transformer/embeddingsizemodeling/jupyter_log.txt' mode='a+' encoding='UTF-8'>

# %%
from src.experiments.experiment_scripts.types.experiment_types import ExperimentType

# %%
list(ExperimentType)
# Out:
# [<ExperimentType.TrainableTransformer: 'Learning'>,
#  <ExperimentType.PoolingStrategyTransformer: 'PoolingStrategyTransformer'>,
#  <ExperimentType.OutputSequenceLengthTransformer: 'OutputSequenceLength'>,
#  <ExperimentType.LearningRateTransformer: 'LearningRateTransformer'>,
#  <ExperimentType.LabelSizeTransformer: 'LabelSizeLabelSizeTransformer'>,
#  <ExperimentType.PreprocessingType: 'PreprocessingType'>,
#  <ExperimentType.TransformerType: 'TransformerType'>,
#  <ExperimentType.PreprocessingTransformer: 'PreprocessingTransformer'>,
#  <ExperimentType.Transformer310Combinations: 'Transformer310Combinations'>,
#  <ExperimentType.Transformer5SentencesCombinations: 'Transformer5SentencesCombinations'>,
#  <ExperimentType.EmbeddingSizeModelingNN: 'EmbeddingSizeModelingNN'>,
#  <ExperimentType.NumberOfAuthorsNN: 'NumberOfAuthorsNN'>,
#  <ExperimentType.NumberOfSentencesNN: 'NumberOfSentencesNN'>,
#  <ExperimentType.NN310Combinations: 'NN310Combinations'>,
#  <ExperimentType.NN5SentencesCombinations: 'NN5SentencesCombinations'>,
#  <ExperimentType.EmbeddingSizeNN: 'EmbeddingSizeNN'>,
#  <ExperimentType.Classic: 'Classic'>,
#  <ExperimentType.ClassicLogisticRegressionLabelSize: 'ClassicLogisticRegressionLabelSize'>,
#  <ExperimentType.ClassicLogisticRegressionPreprocessing: 'ClassicLogisticRegressionPreprocessing'>,
#  <ExperimentType.Classic310Combinations: 'Classic310Combinations'>,
#  <ExperimentType.Classic5SentencesCombinations: 'Classic5SentencesCombinations'>,
#  <ExperimentType.TransformerTest: 'TransformerTest'>,
#  <ExperimentType.NNTest: 'NNTest'>,
#  <ExperimentType.ClassicTest: 'ClassicTest'>]

# %%
from src.experiments.experiment_scripts.experiment_configurations.config import experiment_config
# Out:
# 2022-04-20 16:13:07.781814: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory

# %%
from src.experiments.experiment_scripts.neural_nets.no_transformer.neural_net_runner import NNRunner

# %%
experiment = NNRunner(experiment_type=ExperimentType.EmbeddingSizeModelingNN, config_dict=experiment_config)
# Out:
# [10]
# Loading embeddding
# Embedding dictionaries loaded..
# Loaded configuration [<ExperimentGeneratorPart.DatasetGenerator: 'DatasetGenerator'>, <ExperimentGeneratorPart.ExperimentConfiguration: 'ExperimentConfiguration'>, <ExperimentGeneratorPart.ExperimentArchitecture: 'ExperimentArchitecture'>]

# %%
experiment.run()
# Out:
# Loading dataset from=/home/usp/pro0255/diploma/data/gutenberg/5Authors/Sentence3/data.csv
# Creating shorting method with min = 3
# Creating lemma method with instance <WordNetLemmatizer>
# Specified type CaseInterpunction
# Train (54187,)
# Valid (9563,)
# Test (11250,)
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization (TextVec  (None, 100)              0
#  torization)
#
#  embedding (Embedding)       (None, 100, 10)           519420
#
#  conv1d (Conv1D)             (None, 97, 128)           5248
#
#  max_pooling1d (MaxPooling1D  (None, 48, 128)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 43, 256)           196864
#
#  max_pooling1d_1 (MaxPooling  (None, 21, 256)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 16, 128)           196736
#
#  max_pooling1d_2 (MaxPooling  (None, 8, 128)           0
#  1D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1,206,081
# Trainable params: 1,206,081
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/0!
# Running setup of directory for experiment EmbeddingSizeModelingNN/0
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 91s 105ms/step - loss: 1.2736 - accuracy: 0.4136 - val_loss: 1.0260 - val_accuracy: 0.5260 - time: 90.3779
# Epoch 2/10
# 847/847 [==============================] - 112s 132ms/step - loss: 0.7780 - accuracy: 0.6861 - val_loss: 0.6777 - val_accuracy: 0.7373 - time: 202.7561
# Epoch 3/10
# 847/847 [==============================] - 131s 154ms/step - loss: 0.4537 - accuracy: 0.8307 - val_loss: 0.6144 - val_accuracy: 0.8005 - time: 333.6292
# Epoch 4/10
# 847/847 [==============================] - 107s 126ms/step - loss: 0.2966 - accuracy: 0.8961 - val_loss: 0.5972 - val_accuracy: 0.8234 - time: 440.4537
# Epoch 5/10
# 847/847 [==============================] - 107s 126ms/step - loss: 0.2120 - accuracy: 0.9279 - val_loss: 0.7246 - val_accuracy: 0.8178 - time: 582.4425
# Epoch 6/10
# 847/847 [==============================] - 108s 127ms/step - loss: 0.1613 - accuracy: 0.9458 - val_loss: 0.7242 - val_accuracy: 0.8172 - time: 689.9799
# Epoch 7/10
# 847/847 [==============================] - 107s 126ms/step - loss: 0.1324 - accuracy: 0.9556 - val_loss: 0.8878 - val_accuracy: 0.8116 - time: 831.2141
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_1 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_1 (Embedding)     (None, 100, 30)           1558260
#
#  conv1d_3 (Conv1D)           (None, 97, 128)           15488
#
#  max_pooling1d_3 (MaxPooling  (None, 48, 128)          0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 43, 256)           196864
#
#  max_pooling1d_4 (MaxPooling  (None, 21, 256)          0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 16, 128)           196736
#
#  max_pooling1d_5 (MaxPooling  (None, 8, 128)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 256)               262400
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 64)                16448
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 128)               8320
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 2,255,161
# Trainable params: 2,255,161
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/1!
# Running setup of directory for experiment EmbeddingSizeModelingNN/1
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 142s 166ms/step - loss: 1.6101 - accuracy: 0.2906 - val_loss: 1.6095 - val_accuracy: 0.1956 - time: 141.9653
# Epoch 2/10
# 847/847 [==============================] - 128s 151ms/step - loss: 1.6096 - accuracy: 0.2012 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 271.6450
# Epoch 3/10
# 847/847 [==============================] - 128s 151ms/step - loss: 1.6096 - accuracy: 0.1994 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 399.7561
# Epoch 4/10
# 847/847 [==============================] - 128s 151ms/step - loss: 1.6096 - accuracy: 0.2005 - val_loss: 1.6095 - val_accuracy: 0.1937 - time: 527.5139
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_2 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_2 (Embedding)     (None, 100, 50)           2597100
#
#  conv1d_6 (Conv1D)           (None, 97, 128)           25728
#
#  max_pooling1d_6 (MaxPooling  (None, 48, 128)          0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 43, 256)           196864
#
#  max_pooling1d_7 (MaxPooling  (None, 21, 256)          0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 16, 128)           196736
#
#  max_pooling1d_8 (MaxPooling  (None, 8, 128)           0
#  1D)
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 256)               262400
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 64)                16448
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 128)               8320
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,304,241
# Trainable params: 3,304,241
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/2!
# Running setup of directory for experiment EmbeddingSizeModelingNN/2
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 135s 157ms/step - loss: 1.1966 - accuracy: 0.4321 - val_loss: 0.8332 - val_accuracy: 0.6609 - time: 134.8122
# Epoch 2/10
# 847/847 [==============================] - 131s 155ms/step - loss: 0.6265 - accuracy: 0.7634 - val_loss: 0.5949 - val_accuracy: 0.7871 - time: 266.2094
# Epoch 3/10
# 847/847 [==============================] - 134s 158ms/step - loss: 0.3452 - accuracy: 0.8793 - val_loss: 0.6100 - val_accuracy: 0.8100 - time: 400.6001
# Epoch 4/10
# 847/847 [==============================] - 136s 161ms/step - loss: 0.2262 - accuracy: 0.9229 - val_loss: 0.7536 - val_accuracy: 0.8034 - time: 536.9517
# Epoch 5/10
# 847/847 [==============================] - 139s 164ms/step - loss: 0.1614 - accuracy: 0.9450 - val_loss: 0.7254 - val_accuracy: 0.8172 - time: 675.6228
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_3 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_3 (Embedding)     (None, 100, 70)           3635940
#
#  conv1d_9 (Conv1D)           (None, 97, 128)           35968
#
#  max_pooling1d_9 (MaxPooling  (None, 48, 128)          0
#  1D)
#
#  conv1d_10 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_10 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_11 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_11 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 1024)              0
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 64)                16448
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 128)               8320
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 4,353,321
# Trainable params: 4,353,321
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/3!
# Running setup of directory for experiment EmbeddingSizeModelingNN/3
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 166s 193ms/step - loss: 1.2108 - accuracy: 0.5095 - val_loss: 0.8535 - val_accuracy: 0.6539 - time: 165.2884
# Epoch 2/10
# 847/847 [==============================] - 149s 176ms/step - loss: 0.6173 - accuracy: 0.7699 - val_loss: 0.5942 - val_accuracy: 0.7904 - time: 314.4182
# Epoch 3/10
# 847/847 [==============================] - 152s 180ms/step - loss: 0.3190 - accuracy: 0.8902 - val_loss: 0.6099 - val_accuracy: 0.8163 - time: 466.8840
# Epoch 4/10
# 847/847 [==============================] - 130s 154ms/step - loss: 0.2003 - accuracy: 0.9324 - val_loss: 0.5898 - val_accuracy: 0.8282 - time: 596.7798
# Epoch 5/10
# 847/847 [==============================] - 152s 180ms/step - loss: 0.1450 - accuracy: 0.9508 - val_loss: 0.6611 - val_accuracy: 0.8366 - time: 749.5931
# Epoch 6/10
# 847/847 [==============================] - 143s 169ms/step - loss: 0.1158 - accuracy: 0.9613 - val_loss: 0.7470 - val_accuracy: 0.8285 - time: 892.4811
# Epoch 7/10
# 847/847 [==============================] - 151s 179ms/step - loss: 0.0927 - accuracy: 0.9689 - val_loss: 0.8104 - val_accuracy: 0.8372 - time: 1043.8205
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_4 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_4 (Embedding)     (None, 100, 90)           4674780
#
#  conv1d_12 (Conv1D)          (None, 97, 128)           46208
#
#  max_pooling1d_12 (MaxPoolin  (None, 48, 128)          0
#  g1D)
#
#  conv1d_13 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_13 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_14 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_14 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_16 (Dense)            (None, 256)               262400
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 64)                16448
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_18 (Dense)            (None, 128)               8320
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 5,402,401
# Trainable params: 5,402,401
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/4!
# Running setup of directory for experiment EmbeddingSizeModelingNN/4
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 163s 190ms/step - loss: 1.6102 - accuracy: 0.2961 - val_loss: 1.6094 - val_accuracy: 0.1956 - time: 162.6759
# Epoch 2/10
# 847/847 [==============================] - 162s 191ms/step - loss: 1.2232 - accuracy: 0.4604 - val_loss: 0.8359 - val_accuracy: 0.6810 - time: 325.0669
# Epoch 3/10
# 847/847 [==============================] - 156s 185ms/step - loss: 0.5942 - accuracy: 0.7837 - val_loss: 0.5575 - val_accuracy: 0.8053 - time: 481.4247
# Epoch 4/10
# 847/847 [==============================] - 173s 204ms/step - loss: 0.3052 - accuracy: 0.8963 - val_loss: 0.5472 - val_accuracy: 0.8239 - time: 654.6100
# Epoch 5/10
# 847/847 [==============================] - 168s 198ms/step - loss: 0.1900 - accuracy: 0.9366 - val_loss: 0.6736 - val_accuracy: 0.8220 - time: 822.5768
# Epoch 6/10
# 847/847 [==============================] - 163s 192ms/step - loss: 0.1367 - accuracy: 0.9546 - val_loss: 0.6757 - val_accuracy: 0.8303 - time: 985.3313
# Epoch 7/10
# 847/847 [==============================] - 172s 203ms/step - loss: 0.1037 - accuracy: 0.9653 - val_loss: 0.7359 - val_accuracy: 0.8332 - time: 1157.4767
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_5 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_5 (Embedding)     (None, 100, 110)          5713620
#
#  conv1d_15 (Conv1D)          (None, 97, 128)           56448
#
#  max_pooling1d_15 (MaxPoolin  (None, 48, 128)          0
#  g1D)
#
#  conv1d_16 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_16 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_17 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_17 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_5 (Flatten)         (None, 1024)              0
#  dense_20 (Dense)            (None, 256)               262400
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 64)                16448
#
#  dropout_16 (Dropout)        (None, 64)                0
#
#  dense_22 (Dense)            (None, 128)               8320
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 6,451,481
# Trainable params: 6,451,481
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/5!
# Running setup of directory for experiment EmbeddingSizeModelingNN/5
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 188s 219ms/step - loss: 1.6102 - accuracy: 0.2934 - val_loss: 1.6096 - val_accuracy: 0.1956 - time: 187.0681
# Epoch 2/10
# 847/847 [==============================] - 184s 217ms/step - loss: 1.6096 - accuracy: 0.1987 - val_loss: 1.6096 - val_accuracy: 0.1956 - time: 387.6333
# Epoch 3/10
# 847/847 [==============================] - 182s 215ms/step - loss: 1.6096 - accuracy: 0.2008 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 569.4140
# Epoch 4/10
# 847/847 [==============================] - 174s 206ms/step - loss: 1.6095 - accuracy: 0.1995 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 744.1977
# Epoch 5/10
# 847/847 [==============================] - 184s 217ms/step - loss: 1.6095 - accuracy: 0.2012 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 927.9325
# Epoch 6/10
# 847/847 [==============================] - 169s 200ms/step - loss: 1.6095 - accuracy: 0.2010 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 1096.9876
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_6 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_6 (Embedding)     (None, 100, 130)          6752460
#
#  conv1d_18 (Conv1D)          (None, 97, 128)           66688
#
#  max_pooling1d_18 (MaxPoolin  (None, 48, 128)          0
#  g1D)
#
#  conv1d_19 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_19 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_20 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_20 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_6 (Flatten)         (None, 1024)              0
#
#  dense_24 (Dense)            (None, 256)               262400
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 64)                16448
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 128)               8320
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_27 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 7,500,561
# Trainable params: 7,500,561
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/6!
# Running setup of directory for experiment EmbeddingSizeModelingNN/6
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 186s 217ms/step - loss: 1.2509 - accuracy: 0.3663 - val_loss: 0.9952 - val_accuracy: 0.5657 - time: 185.0657
# Epoch 2/10
# 847/847 [==============================] - 185s 219ms/step - loss: 0.6908 - accuracy: 0.7077 - val_loss: 0.6050 - val_accuracy: 0.7816 - time: 370.8901
# Epoch 3/10
# 847/847 [==============================] - 185s 219ms/step - loss: 0.3537 - accuracy: 0.8745 - val_loss: 0.5859 - val_accuracy: 0.8189 - time: 556.7787
# Epoch 4/10
# 847/847 [==============================] - 181s 214ms/step - loss: 0.2087 - accuracy: 0.9288 - val_loss: 0.6551 - val_accuracy: 0.8188 - time: 738.6818
# Epoch 5/10
# 847/847 [==============================] - 182s 215ms/step - loss: 0.1448 - accuracy: 0.9528 - val_loss: 0.7038 - val_accuracy: 0.8202 - time: 920.5067
# Epoch 6/10
# 847/847 [==============================] - 182s 215ms/step - loss: 0.1099 - accuracy: 0.9628 - val_loss: 0.7254 - val_accuracy: 0.8278 - time: 1102.3030
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_7 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_7 (Embedding)     (None, 100, 150)          7791300
#
#  conv1d_21 (Conv1D)          (None, 97, 128)           76928
#
#  max_pooling1d_21 (MaxPoolin  (None, 48, 128)          0
#  g1D)
#
#  conv1d_22 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_22 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_23 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_23 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_7 (Flatten)         (None, 1024)              0
#
#  dense_28 (Dense)            (None, 256)               262400
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 64)                16448
#
#  dropout_22 (Dropout)        (None, 64)                0
#
#  dense_30 (Dense)            (None, 128)               8320
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_31 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 8,549,641
# Trainable params: 8,549,641
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/7!
# Running setup of directory for experiment EmbeddingSizeModelingNN/7
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 210s 244ms/step - loss: 1.1745 - accuracy: 0.5327 - val_loss: 0.7859 - val_accuracy: 0.6819 - time: 209.2709
# Epoch 2/10
# 847/847 [==============================] - 186s 220ms/step - loss: 0.5701 - accuracy: 0.7908 - val_loss: 0.5607 - val_accuracy: 0.8004 - time: 395.9568
# Epoch 3/10
# 847/847 [==============================] - 204s 241ms/step - loss: 0.2985 - accuracy: 0.8986 - val_loss: 0.5910 - val_accuracy: 0.8267 - time: 600.3609
# Epoch 4/10
# 847/847 [==============================] - 191s 226ms/step - loss: 0.1882 - accuracy: 0.9376 - val_loss: 0.6588 - val_accuracy: 0.8298 - time: 791.6924
# Epoch 5/10
# 847/847 [==============================] - 188s 222ms/step - loss: 0.1350 - accuracy: 0.9560 - val_loss: 0.6508 - val_accuracy: 0.8407 - time: 979.6997
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_8 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_8 (Embedding)     (None, 100, 170)          8830140
#
#  conv1d_24 (Conv1D)          (None, 97, 128)           87168
#
#  max_pooling1d_24 (MaxPoolin  (None, 48, 128)          0
#  g1D)
#
#  conv1d_25 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_25 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_26 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_26 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_8 (Flatten)         (None, 1024)              0
#
#  dense_32 (Dense)            (None, 256)               262400
#
#  dropout_24 (Dropout)        (None, 256)               0
#
#  dense_33 (Dense)            (None, 64)                16448
#
#  dropout_25 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 128)               8320
#
#  dropout_26 (Dropout)        (None, 128)               0
#
#  dense_35 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 9,598,721
# Trainable params: 9,598,721
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/8!
# Running setup of directory for experiment EmbeddingSizeModelingNN/8
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 193s 226ms/step - loss: 1.1411 - accuracy: 0.5585 - val_loss: 0.8129 - val_accuracy: 0.6801 - time: 192.4224
# Epoch 2/10
# 847/847 [==============================] - 193s 228ms/step - loss: 0.5768 - accuracy: 0.7890 - val_loss: 0.5515 - val_accuracy: 0.8100 - time: 385.7724
# Epoch 3/10
# 847/847 [==============================] - 209s 246ms/step - loss: 0.3022 - accuracy: 0.8975 - val_loss: 0.5633 - val_accuracy: 0.8217 - time: 603.7635
# Epoch 4/10
# 847/847 [==============================] - 200s 236ms/step - loss: 0.1875 - accuracy: 0.9385 - val_loss: 0.6559 - val_accuracy: 0.8300 - time: 803.6897
# Epoch 5/10
# 847/847 [==============================] - 200s 236ms/step - loss: 0.1313 - accuracy: 0.9568 - val_loss: 0.6962 - val_accuracy: 0.8384 - time: 1003.5761
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_9 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_9 (Embedding)     (None, 100, 190)          9868980
#  conv1d_27 (Conv1D)          (None, 97, 128)           97408
#
#  max_pooling1d_27 (MaxPoolin  (None, 48, 128)          0
#  g1D)
#
#  conv1d_28 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_28 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_29 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_29 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_9 (Flatten)         (None, 1024)              0
#
#  dense_36 (Dense)            (None, 256)               262400
#
#  dropout_27 (Dropout)        (None, 256)               0
#
#  dense_37 (Dense)            (None, 64)                16448
#
#  dropout_28 (Dropout)        (None, 64)                0
#
#  dense_38 (Dense)            (None, 128)               8320
#
#  dropout_29 (Dropout)        (None, 128)               0
#
#  dense_39 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 10,647,801
# Trainable params: 10,647,801
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/9!
# Running setup of directory for experiment EmbeddingSizeModelingNN/9
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 263s 308ms/step - loss: 1.2153 - accuracy: 0.5108 - val_loss: 0.8682 - val_accuracy: 0.6306 - time: 262.9361
# Epoch 2/10
# 847/847 [==============================] - 241s 285ms/step - loss: 0.6763 - accuracy: 0.7216 - val_loss: 0.6536 - val_accuracy: 0.7575 - time: 504.6140
# Epoch 3/10
# 847/847 [==============================] - 276s 326ms/step - loss: 0.3526 - accuracy: 0.8759 - val_loss: 0.6156 - val_accuracy: 0.8087 - time: 780.9047
# Epoch 4/10
# 847/847 [==============================] - 266s 314ms/step - loss: 0.2058 - accuracy: 0.9314 - val_loss: 0.6197 - val_accuracy: 0.8310 - time: 1047.5090
# Epoch 5/10
# 847/847 [==============================] - 278s 328ms/step - loss: 0.1388 - accuracy: 0.9539 - val_loss: 0.7085 - val_accuracy: 0.8330 - time: 1325.4390
# Epoch 6/10
# 847/847 [==============================] - 275s 325ms/step - loss: 0.1067 - accuracy: 0.9643 - val_loss: 0.7123 - val_accuracy: 0.8356 - time: 1644.5639
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_10 (Text  (None, 100)              0
#  Vectorization)
#
#  embedding_10 (Embedding)    (None, 100, 210)          10907820
#
#  conv1d_30 (Conv1D)          (None, 97, 128)           107648
#
#  max_pooling1d_30 (MaxPoolin  (None, 48, 128)          0
#  g1D)
#
#  conv1d_31 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_31 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_32 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_32 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_10 (Flatten)        (None, 1024)              0
#
#  dense_40 (Dense)            (None, 256)               262400
#
#  dropout_30 (Dropout)        (None, 256)               0
#
#  dense_41 (Dense)            (None, 64)                16448
#
#  dropout_31 (Dropout)        (None, 64)                0
#
#  dense_42 (Dense)            (None, 128)               8320
#
#  dropout_32 (Dropout)        (None, 128)               0
#
#  dense_43 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 11,696,881
# Trainable params: 11,696,881
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/10!
# Running setup of directory for experiment EmbeddingSizeModelingNN/10
# Compiling model
# Fitting model
# Epoch 1/10
# ...
#
#  flatten_25 (Flatten)        (None, 19000)             0
#
#  dense_100 (Dense)           (None, 64)                1216064
#
#  dropout_75 (Dropout)        (None, 64)                0
#
#  dense_101 (Dense)           (None, 32)                2080
#
#  dropout_76 (Dropout)        (None, 32)                0
#
#  dense_102 (Dense)           (None, 64)                2112
#
#  dropout_77 (Dropout)        (None, 64)                0
#
#  dense_103 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 11,089,561
# Trainable params: 11,089,561
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/25!
# Running setup of directory for experiment EmbeddingSizeModelingNN/25
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 191s 225ms/step - loss: 1.0588 - accuracy: 0.5999 - val_loss: 0.6494 - val_accuracy: 0.7650 - time: 190.7318
# Epoch 2/10
# 847/847 [==============================] - 195s 230ms/step - loss: 0.4204 - accuracy: 0.8569 - val_loss: 0.5141 - val_accuracy: 0.8291 - time: 386.1305
# Epoch 3/10
# 847/847 [==============================] - 194s 229ms/step - loss: 0.1935 - accuracy: 0.9374 - val_loss: 0.5725 - val_accuracy: 0.8301 - time: 587.0152
# Epoch 4/10
# 847/847 [==============================] - 197s 233ms/step - loss: 0.1174 - accuracy: 0.9620 - val_loss: 0.6666 - val_accuracy: 0.8309 - time: 784.5624
# Epoch 5/10
# 847/847 [==============================] - 191s 225ms/step - loss: 0.0863 - accuracy: 0.9713 - val_loss: 0.7800 - val_accuracy: 0.8289 - time: 979.4927
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_26 (Text  (None, 100)              0
#  Vectorization)
#
#  embedding_26 (Embedding)    (None, 100, 210)          10907820
#
#  flatten_26 (Flatten)        (None, 21000)             0
#
#  dense_104 (Dense)           (None, 64)                1344064
#
#  dropout_78 (Dropout)        (None, 64)                0
#
#  dense_105 (Dense)           (None, 32)                2080
#
#  dropout_79 (Dropout)        (None, 32)                0
#
#  dense_106 (Dense)           (None, 64)                2112
#
#  dropout_80 (Dropout)        (None, 64)                0
#
#  dense_107 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 12,256,401
# Trainable params: 12,256,401
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/26!
# Running setup of directory for experiment EmbeddingSizeModelingNN/26
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 218s 256ms/step - loss: 1.0533 - accuracy: 0.6038 - val_loss: 0.7072 - val_accuracy: 0.7267 - time: 217.2499
# Epoch 2/10
# 847/847 [==============================] - 219s 259ms/step - loss: 0.4571 - accuracy: 0.8340 - val_loss: 0.6275 - val_accuracy: 0.7984 - time: 436.6550
# Epoch 3/10
# 847/847 [==============================] - 218s 257ms/step - loss: 0.2095 - accuracy: 0.9309 - val_loss: 0.7348 - val_accuracy: 0.8037 - time: 655.0620
# Epoch 4/10
# 847/847 [==============================] - 218s 257ms/step - loss: 0.1281 - accuracy: 0.9593 - val_loss: 0.7531 - val_accuracy: 0.8179 - time: 872.9707
# Epoch 5/10
# 847/847 [==============================] - 217s 256ms/step - loss: 0.0899 - accuracy: 0.9709 - val_loss: 0.8585 - val_accuracy: 0.8168 - time: 1089.7785
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_28 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_27 (Text  (None, 100)              0
#  Vectorization)
#
#  embedding_27 (Embedding)    (None, 100, 230)          11946660
#
#  flatten_27 (Flatten)        (None, 23000)             0
#
#  dense_108 (Dense)           (None, 64)                1472064
#
#  dropout_81 (Dropout)        (None, 64)                0
#
#  dense_109 (Dense)           (None, 32)                2080
#
#  dropout_82 (Dropout)        (None, 32)                0
#
#  dense_110 (Dense)           (None, 64)                2112
#
#  dropout_83 (Dropout)        (None, 64)                0
#
#  dense_111 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 13,423,241
# Trainable params: 13,423,241
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/27!
# Running setup of directory for experiment EmbeddingSizeModelingNN/27
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 239s 281ms/step - loss: 1.0298 - accuracy: 0.6213 - val_loss: 0.6471 - val_accuracy: 0.7635 - time: 238.8004
# Epoch 2/10
# 847/847 [==============================] - 236s 279ms/step - loss: 0.3967 - accuracy: 0.8659 - val_loss: 0.5231 - val_accuracy: 0.8242 - time: 474.9831
# Epoch 3/10
# 847/847 [==============================] - 214s 253ms/step - loss: 0.1774 - accuracy: 0.9414 - val_loss: 0.6467 - val_accuracy: 0.8190 - time: 689.7424
# Epoch 4/10
# 847/847 [==============================] - 213s 251ms/step - loss: 0.1118 - accuracy: 0.9642 - val_loss: 0.6599 - val_accuracy: 0.8319 - time: 902.7406
# Epoch 5/10
# 847/847 [==============================] - 210s 248ms/step - loss: 0.0821 - accuracy: 0.9722 - val_loss: 0.7441 - val_accuracy: 0.8197 - time: 1112.5491
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_29 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_28 (Text  (None, 100)              0
#  Vectorization)
#
#  embedding_28 (Embedding)    (None, 100, 250)          12985500
#
#  flatten_28 (Flatten)        (None, 25000)             0
#
#  dense_112 (Dense)           (None, 64)                1600064
#
#  dropout_84 (Dropout)        (None, 64)                0
#
#  dense_113 (Dense)           (None, 32)                2080
#
#  dropout_85 (Dropout)        (None, 32)                0
#
#  dense_114 (Dense)           (None, 64)                2112
#
#  dropout_86 (Dropout)        (None, 64)                0
#
#  dense_115 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 14,590,081
# Trainable params: 14,590,081
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/28!
# Running setup of directory for experiment EmbeddingSizeModelingNN/28
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 249s 292ms/step - loss: 1.0124 - accuracy: 0.6320 - val_loss: 0.5994 - val_accuracy: 0.7859 - time: 248.0617
# Epoch 2/10
# 847/847 [==============================] - 246s 291ms/step - loss: 0.3724 - accuracy: 0.8738 - val_loss: 0.5365 - val_accuracy: 0.8191 - time: 494.9042
# Epoch 3/10
# 847/847 [==============================] - 251s 297ms/step - loss: 0.1772 - accuracy: 0.9418 - val_loss: 0.6339 - val_accuracy: 0.8247 - time: 746.5318
# Epoch 4/10
# 847/847 [==============================] - 256s 302ms/step - loss: 0.1068 - accuracy: 0.9642 - val_loss: 0.6933 - val_accuracy: 0.8218 - time: 1002.2953
# Epoch 5/10
# 847/847 [==============================] - 255s 301ms/step - loss: 0.0843 - accuracy: 0.9719 - val_loss: 0.7857 - val_accuracy: 0.8187 - time: 1256.8000
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_30 (InputLayer)       [(None, 1)]               0
#  text_vectorization_29 (Text  (None, 100)              0
#  Vectorization)
#
#  embedding_29 (Embedding)    (None, 100, 270)          14024340
#
#  flatten_29 (Flatten)        (None, 27000)             0
#
#  dense_116 (Dense)           (None, 64)                1728064
#
#  dropout_87 (Dropout)        (None, 64)                0
#
#  dense_117 (Dense)           (None, 32)                2080
#
#  dropout_88 (Dropout)        (None, 32)                0
#
#  dense_118 (Dense)           (None, 64)                2112
#
#  dropout_89 (Dropout)        (None, 64)                0
#
#  dense_119 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 15,756,921
# Trainable params: 15,756,921
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for EmbeddingSizeModelingNN/29!
# Running setup of directory for experiment EmbeddingSizeModelingNN/29
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 278s 326ms/step - loss: 1.0510 - accuracy: 0.6107 - val_loss: 0.6178 - val_accuracy: 0.7788 - time: 277.1132
# Epoch 2/10
# 847/847 [==============================] - 268s 316ms/step - loss: 0.3967 - accuracy: 0.8654 - val_loss: 0.5597 - val_accuracy: 0.8092 - time: 591.1188
# Epoch 3/10
# 847/847 [==============================] - 267s 315ms/step - loss: 0.1858 - accuracy: 0.9412 - val_loss: 0.6365 - val_accuracy: 0.8095 - time: 858.2896
# Epoch 4/10
# 847/847 [==============================] - 244s 288ms/step - loss: 0.1120 - accuracy: 0.9627 - val_loss: 0.7586 - val_accuracy: 0.8220 - time: 1102.3538
# Epoch 5/10
# 847/847 [==============================] - 220s 260ms/step - loss: 0.0862 - accuracy: 0.9714 - val_loss: 0.9033 - val_accuracy: 0.8219 - time: 1322.7260
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fa1cf7e5040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7f9ec076dc10>
