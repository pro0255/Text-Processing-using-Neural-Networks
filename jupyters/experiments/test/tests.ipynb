# %%
import os
import sys

def adding_module_path():
    module_path = os.path.abspath(os.path.sep.join([".."]*3))

    if module_path not in sys.path:
        sys.path.append(module_path)

adding_module_path()

from src.config.run_prep import run_prep
from src.utils.log_juypter import add_experiment_jupyter_logger

run_prep()
add_experiment_jupyter_logger(os.getcwd())
# Out:
# Running preperation of packages
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# <_io.TextIOWrapper name='/home/usp/pro0255/diploma/jupyters/experiments/test/jupyter_log.txt' mode='a+' encoding='UTF-8'>

# %%
from src.types.test_types import TestType

# %%
list(TestType)
# Out:
# [<TestType.Transformer: 'Transformer'>,
#  <TestType.Classic: 'Classic'>,
#  <TestType.NN: 'NN'>]

# %%
from src.experiments.experiment_scripts.test.test_runner import TestRunner
# Out:
# [5]
# [5]
# [5]
# [5]
# [10]
# [5]
# [10]
# Loading embeddding
# Already loaded model=glove-wiki-gigaword-300
# Already loaded model=word2vec-google-news-300
# Embedding dictionaries loaded..
# [1]
# [1]
# Loading embeddding
# Already loaded model=glove-wiki-gigaword-300
# Already loaded model=word2vec-google-news-300
# Embedding dictionaries loaded..
# 2022-04-12 16:47:43.968151: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory

# %%
test_runner = TestRunner()

# %%
tests_to_run = list(TestType)

# %%
test_runner.run_tests(tests_to_run)
# Out:
# Running transformer tests!
# Loading dataset from=/home/usp/pro0255/diploma/data/gutenberg/5Authors/Sentence3/data.csv
# Creating shorting method with min = 3
# Creating lemma method with instance <WordNetLemmatizer>
# Specified type CaseInterpunction
# Train (361,)
# Valid (64,)
# Test (75,)
# Tokenizer with max len = 50
# Model: "TransformerDenseHead"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 50)]         0           []
#
#  attention_mask (InputLayer)    [(None, 50)]         0           []
#
#  tf_distil_bert_model (TFDistil  TFBaseModelOutput(l  66362880   ['input_ids[0][0]',
#  BertModel)                     ast_hidden_state=(N               'attention_mask[0][0]']
#                                 one, 50, 768),
#                                  hidden_states=((No
#                                 ne, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768)),
#                                  attentions=None)
#
#  bert_pooling_layer (BertPoolin  (None, 768)         0           ['tf_distil_bert_model[0][0]',
#  gLayer)                                                          'tf_distil_bert_model[0][1]',
#                                                                   'tf_distil_bert_model[0][2]',
#                                                                   'tf_distil_bert_model[0][3]',
#                                                                   'tf_distil_bert_model[0][4]',
#                                                                   'tf_distil_bert_model[0][5]',
#                                                                   'tf_distil_bert_model[0][6]',
#                                                                   'tf_distil_bert_model[0][7]']
#
#  dropout_19 (Dropout)           (None, 768)          0           ['bert_pooling_layer[0][0]']
#
#  dense (Dense)                  (None, 64)           49216       ['dropout_19[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64)          256         ['dense[0][0]']
#  alization)
#
#  dense_1 (Dense)                (None, 64)           4160        ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64)          256         ['dense_1[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 5)            325         ['batch_normalization_1[0][0]']
#
# ==================================================================================================
# Total params: 66,417,093
# Trainable params: 66,416,837
# Non-trainable params: 256
# __________________________________________________________________________________________________
# Creating new experiment summarization for TransformerTest/4!
# Running setup of directory for experiment TransformerTest/4
# Compiling model
# Fitting model
# 6/6 [==============================] - 59s 7s/step - loss: 2.1338 - accuracy: 0.2493 - val_loss: 1.6162 - val_accuracy: 0.2500 - time: 58.0448
# Loading best weights to model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Tokenizer with max len = 50
# Model: "TransformerDenseHead"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 50)]         0           []
#
#  attention_mask (InputLayer)    [(None, 50)]         0           []
#
#  tf_distil_bert_model_1 (TFDist  TFBaseModelOutput(l  66362880   ['input_ids[0][0]',
#  ilBertModel)                   ast_hidden_state=(N               'attention_mask[0][0]']
#                                 one, 50, 768),
#                                  hidden_states=((No
#                                 ne, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768),
#                                  (None, 50, 768)),
#                                  attentions=None)
#
#  bert_pooling_layer_1 (BertPool  (None, 768)         0           ['tf_distil_bert_model_1[0][0]',
#  ingLayer)                                                        'tf_distil_bert_model_1[0][1]',
#                                                                   'tf_distil_bert_model_1[0][2]',
#                                                                   'tf_distil_bert_model_1[0][3]',
#                                                                   'tf_distil_bert_model_1[0][4]',
#                                                                   'tf_distil_bert_model_1[0][5]',
#                                                                   'tf_distil_bert_model_1[0][6]',
#                                                                   'tf_distil_bert_model_1[0][7]']
#  dropout_39 (Dropout)           (None, 768)          0           ['bert_pooling_layer_1[0][0]']
#
#  dense_3 (Dense)                (None, 64)           49216       ['dropout_39[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64)          256         ['dense_3[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 64)           4160        ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64)          256         ['dense_4[0][0]']
#  rmalization)
#
#  dense_5 (Dense)                (None, 5)            325         ['batch_normalization_3[0][0]']
#
# ==================================================================================================
# Total params: 66,417,093
# Trainable params: 53,957
# Non-trainable params: 66,363,136
# __________________________________________________________________________________________________
# Creating new experiment summarization for TransformerTest/5!
# Running setup of directory for experiment TransformerTest/5
# Compiling model
# Fitting model
# 6/6 [==============================] - 34s 4s/step - loss: 2.4516 - accuracy: 0.2024 - val_loss: 2.1922 - val_accuracy: 0.2188 - time: 33.3173
# Loading best weights to model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# End of transformer tests!
# Running transformer tests!
# Loading dataset from=/home/usp/pro0255/diploma/data/gutenberg/5Authors/Sentence3/data.csv
# Creating shorting method with min = 3
# Creating lemma method with instance <WordNetLemmatizer>
# Specified type CaseInterpunction
# Train (361,)
# Valid (64,)
# Test (75,)
#
#
# Creating new experiment summarization for !
# New vectorization
# Fitting vetorizer with name CountVectorizer
# Fitting vectorizer in ['CountVectorizer', 'TfidfVectorizer']
# End train
# Fitting vetorizer with name CountVectorizer
# Fitting vectorizer in ['CountVectorizer', 'TfidfVectorizer']
# End test
# End of vectorization
# Current name of vectorizer CountVectorizer in [('CountVectorizer', 'BoW'), ('TfidfVectorizer', 'TfIdf'), ('GloveVectorizer', 'Glove'), ('Word2VecVectorizer', 'Word2Vec'), ('BertBaseUncasedVectorizer', 'Transformer'), ('DistilBertBaseUncasedVectorizer', 'Transformer'), ('ElectraSmallVectorizer', 'Transformer')]
# Current name of instance GaussianNB in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance NaiveBayesClassifier
# Running setup of directory for experiment ClassicTest/28
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance SGDClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance LinearClassifier
# Running setup of directory for experiment ClassicTest/29
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance RandomForestClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance RandomForestClassifier
# Running setup of directory for experiment ClassicTest/30
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance KNeighborsClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance KNeighborsClassifier
# Running setup of directory for experiment ClassicTest/31
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Error when getting extra field for experiment ClassicTest/31!
#
#
# Creating new experiment summarization for !
# New vectorization
# Fitting vetorizer with name TfidfVectorizer
# Fitting vectorizer in ['CountVectorizer', 'TfidfVectorizer']
# End train
# Fitting vetorizer with name TfidfVectorizer
# Fitting vectorizer in ['CountVectorizer', 'TfidfVectorizer']
# End test
# End of vectorization
# Current name of vectorizer TfidfVectorizer in [('CountVectorizer', 'BoW'), ('TfidfVectorizer', 'TfIdf'), ('GloveVectorizer', 'Glove'), ('Word2VecVectorizer', 'Word2Vec'), ('BertBaseUncasedVectorizer', 'Transformer'), ('DistilBertBaseUncasedVectorizer', 'Transformer'), ('ElectraSmallVectorizer', 'Transformer')]
# Current name of instance GaussianNB in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance NaiveBayesClassifier
# Running setup of directory for experiment ClassicTest/32
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance SGDClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance LinearClassifier
# Running setup of directory for experiment ClassicTest/33
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance RandomForestClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance RandomForestClassifier
# Running setup of directory for experiment ClassicTest/34
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance KNeighborsClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance KNeighborsClassifier
# Running setup of directory for experiment ClassicTest/35
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Error when getting extra field for experiment ClassicTest/35!
#
#
# Creating new experiment summarization for !
# New vectorization
# Fitting vetorizer with name GloveVectorizer
# Fitting vectorizer in ['GloveVectorizer', 'Word2VecVectorizer']
# Downloading model word2vec-google-news-300!
# Already loaded model=word2vec-google-news-300
# Current embedding size is 300
# Transforming 361, 0 0
# Missed=3085, counter=22901, accuracy=13.471027466049518
# End train
# Fitting vetorizer with name GloveVectorizer
# Fitting vectorizer in ['GloveVectorizer', 'Word2VecVectorizer']
# Already downloaded
# Transforming 75, 0 0
# Missed=592, counter=4519, accuracy=13.100243416685107
# End test
# End of vectorization
# Current name of vectorizer GloveVectorizer in [('CountVectorizer', 'BoW'), ('TfidfVectorizer', 'TfIdf'), ('GloveVectorizer', 'Glove'), ('Word2VecVectorizer', 'Word2Vec'), ('BertBaseUncasedVectorizer', 'Transformer'), ('DistilBertBaseUncasedVectorizer', 'Transformer'), ('ElectraSmallVectorizer', 'Transformer')]
# Current name of instance GaussianNB in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance NaiveBayesClassifier
# Running setup of directory for experiment ClassicTest/36
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance SGDClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance LinearClassifier
# Running setup of directory for experiment ClassicTest/37
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance RandomForestClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance RandomForestClassifier
# Running setup of directory for experiment ClassicTest/38
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance KNeighborsClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance KNeighborsClassifier
# Running setup of directory for experiment ClassicTest/39
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Error when getting extra field for experiment ClassicTest/39!
#
#
# Creating new experiment summarization for !
# New vectorization
# Fitting vetorizer with name Word2VecVectorizer
# Fitting vectorizer in ['GloveVectorizer', 'Word2VecVectorizer']
# Downloading model glove-wiki-gigaword-300!
# Already loaded model=glove-wiki-gigaword-300
# Current embedding size is 300
# Transforming 361, 0 0
# Missed=192, counter=22901, accuracy=0.8383913366228549
# End train
# Fitting vetorizer with name Word2VecVectorizer
# Fitting vectorizer in ['GloveVectorizer', 'Word2VecVectorizer']
# Already downloaded
# Transforming 75, 0 0
# Missed=31, counter=4519, accuracy=0.6859924762115512
# End test
# End of vectorization
# Current name of vectorizer Word2VecVectorizer in [('CountVectorizer', 'BoW'), ('TfidfVectorizer', 'TfIdf'), ('GloveVectorizer', 'Glove'), ('Word2VecVectorizer', 'Word2Vec'), ('BertBaseUncasedVectorizer', 'Transformer'), ('DistilBertBaseUncasedVectorizer', 'Transformer'), ('ElectraSmallVectorizer', 'Transformer')]
# Current name of instance GaussianNB in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance NaiveBayesClassifier
# Running setup of directory for experiment ClassicTest/40
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance SGDClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance LinearClassifier
# Running setup of directory for experiment ClassicTest/41
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance RandomForestClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance RandomForestClassifier
# Running setup of directory for experiment ClassicTest/42
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance KNeighborsClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance KNeighborsClassifier
# Running setup of directory for experiment ClassicTest/43
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Error when getting extra field for experiment ClassicTest/43!
#
#
# Creating new experiment summarization for !
# Setting pooling strategy TransformerPoolingStrategySelection.LastLayerCLS
# New vectorization
# Fitting vetorizer with name ElectraSmallVectorizer
# Fitting vectorizer in ['ElectraSmallVectorizer', 'BertBaseUncasedVectorizer', 'DistilBertBaseUncasedVectorizer']
# Tokenizer with max len = None
# End train
# Fitting vetorizer with name ElectraSmallVectorizer
# Fitting vectorizer in ['ElectraSmallVectorizer', 'BertBaseUncasedVectorizer', 'DistilBertBaseUncasedVectorizer']
# Tokenizer with max len = None
# End test
# End of vectorization
# Current name of vectorizer ElectraSmallVectorizer in [('CountVectorizer', 'BoW'), ('TfidfVectorizer', 'TfIdf'), ('GloveVectorizer', 'Glove'), ('Word2VecVectorizer', 'Word2Vec'), ('BertBaseUncasedVectorizer', 'Transformer'), ('DistilBertBaseUncasedVectorizer', 'Transformer'), ('ElectraSmallVectorizer', 'Transformer')]
# Current name of instance GaussianNB in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance NaiveBayesClassifier
# Running setup of directory for experiment ClassicTest/44
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance SGDClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance LinearClassifier
# Running setup of directory for experiment ClassicTest/45
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance RandomForestClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance RandomForestClassifier
# Running setup of directory for experiment ClassicTest/46
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance KNeighborsClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance KNeighborsClassifier
# Running setup of directory for experiment ClassicTest/47
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Error when getting extra field for experiment ClassicTest/47!
#
#
# Creating new experiment summarization for !
# Setting pooling strategy TransformerPoolingStrategySelection.LastLayerCLS
# New vectorization
# Fitting vetorizer with name BertBaseUncasedVectorizer
# Fitting vectorizer in ['ElectraSmallVectorizer', 'BertBaseUncasedVectorizer', 'DistilBertBaseUncasedVectorizer']
# Tokenizer with max len = None
# End train
# Fitting vetorizer with name BertBaseUncasedVectorizer
# Fitting vectorizer in ['ElectraSmallVectorizer', 'BertBaseUncasedVectorizer', 'DistilBertBaseUncasedVectorizer']
# Tokenizer with max len = None
# End test
# End of vectorization
# Current name of vectorizer BertBaseUncasedVectorizer in [('CountVectorizer', 'BoW'), ('TfidfVectorizer', 'TfIdf'), ('GloveVectorizer', 'Glove'), ('Word2VecVectorizer', 'Word2Vec'), ('BertBaseUncasedVectorizer', 'Transformer'), ('DistilBertBaseUncasedVectorizer', 'Transformer'), ('ElectraSmallVectorizer', 'Transformer')]
# Current name of instance GaussianNB in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance NaiveBayesClassifier
# Running setup of directory for experiment ClassicTest/48
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance SGDClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance LinearClassifier
# Running setup of directory for experiment ClassicTest/49
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance RandomForestClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance RandomForestClassifier
# Running setup of directory for experiment ClassicTest/50
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance KNeighborsClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance KNeighborsClassifier
# Running setup of directory for experiment ClassicTest/51
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Error when getting extra field for experiment ClassicTest/51!
#
#
# Creating new experiment summarization for !
# Setting pooling strategy TransformerPoolingStrategySelection.LastLayerCLS
# New vectorization
# Fitting vetorizer with name DistilBertBaseUncasedVectorizer
# Fitting vectorizer in ['ElectraSmallVectorizer', 'BertBaseUncasedVectorizer', 'DistilBertBaseUncasedVectorizer']
# Tokenizer with max len = None
# End train
# Fitting vetorizer with name DistilBertBaseUncasedVectorizer
# Fitting vectorizer in ['ElectraSmallVectorizer', 'BertBaseUncasedVectorizer', 'DistilBertBaseUncasedVectorizer']
# Tokenizer with max len = None
# End test
# End of vectorization
# Current name of vectorizer DistilBertBaseUncasedVectorizer in [('CountVectorizer', 'BoW'), ('TfidfVectorizer', 'TfIdf'), ('GloveVectorizer', 'Glove'), ('Word2VecVectorizer', 'Word2Vec'), ('BertBaseUncasedVectorizer', 'Transformer'), ('DistilBertBaseUncasedVectorizer', 'Transformer'), ('ElectraSmallVectorizer', 'Transformer')]
# Current name of instance GaussianNB in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance NaiveBayesClassifier
# Running setup of directory for experiment ClassicTest/52
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance SGDClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance LinearClassifier
# Running setup of directory for experiment ClassicTest/53
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance RandomForestClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance RandomForestClassifier
# Running setup of directory for experiment ClassicTest/54
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Current name of instance KNeighborsClassifier in [('SGDClassifier', 'LinearClassifier'), ('GaussianNB', 'NaiveBayesClassifier'), ('RandomForestClassifier', 'RandomForestClassifier'), ('KNeighborsClassifier', 'KNeighborsClassifier')]
# Current predict instance KNeighborsClassifier
# Running setup of directory for experiment ClassicTest/55
# Fitting model
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# Error when getting extra field for experiment ClassicTest/55!
# End of classic tests!
# Running NN tests!
# ExperimentType.NNTest
# Loading dataset from=/home/usp/pro0255/diploma/data/gutenberg/5Authors/Sentence3/data.csv
# Creating shorting method with min = 3
# Creating lemma method with instance <WordNetLemmatizer>
# Specified type CaseInterpunction
# Train (361,)
# Valid (64,)
# Test (75,)
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization (TextVec  (None, 130)              0
#  torization)
#
#  embedding (Embedding)       (None, 130, 50)           2500
#
#  conv1d (Conv1D)             (None, 127, 128)          25728
#
#  max_pooling1d (MaxPooling1D  (None, 63, 128)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 58, 256)           196864
#
#  max_pooling1d_1 (MaxPooling  (None, 29, 256)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 24, 128)           196736
#
#  max_pooling1d_2 (MaxPooling  (None, 12, 128)          0
#  1D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense_6 (Dense)             (None, 256)               393472
#
#  dropout_226 (Dropout)       (None, 256)               0
#
#  dense_7 (Dense)             (None, 64)                16448
#
#  dropout_227 (Dropout)       (None, 64)                0
#
#  dense_8 (Dense)             (None, 128)               8320
#
#  dropout_228 (Dropout)       (None, 128)               0
#
#  dense_9 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 840,713
# Trainable params: 840,713
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NNTest/30!
# Running setup of directory for experiment NNTest/30
# Compiling model
# Fitting model
# 6/6 [==============================] - 3s 213ms/step - loss: 1.6108 - accuracy: 0.1765 - val_loss: 1.6117 - val_accuracy: 0.1250 - time: 2.7667
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_1 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_1 (Embedding)     (None, 130, 150)          7500
#
#  conv1d_3 (Conv1D)           (None, 127, 128)          76928
#
#  max_pooling1d_3 (MaxPooling  (None, 63, 128)          0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 58, 256)           196864
#
#  max_pooling1d_4 (MaxPooling  (None, 29, 256)          0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 24, 128)           196736
#
#  max_pooling1d_5 (MaxPooling  (None, 12, 128)          0
#  1D)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
#  dense_10 (Dense)            (None, 256)               393472
#
#  dropout_229 (Dropout)       (None, 256)               0
#
#  dense_11 (Dense)            (None, 64)                16448
#
#  dropout_230 (Dropout)       (None, 64)                0
#
#  dense_12 (Dense)            (None, 128)               8320
#
#  dropout_231 (Dropout)       (None, 128)               0
#
#  dense_13 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 896,913
# Trainable params: 896,913
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NNTest/31!
# Running setup of directory for experiment NNTest/31
# Compiling model
# Fitting model
# 6/6 [==============================] - 4s 232ms/step - loss: 1.6104 - accuracy: 0.2047 - val_loss: 1.6004 - val_accuracy: 0.2031 - time: 3.8972
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_2 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_2 (Embedding)     (None, 130, 300)          15000
#
#  conv1d_6 (Conv1D)           (None, 127, 128)          153728
#
#  max_pooling1d_6 (MaxPooling  (None, 63, 128)          0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 58, 256)           196864
#
#  max_pooling1d_7 (MaxPooling  (None, 29, 256)          0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 24, 128)           196736
#
#  max_pooling1d_8 (MaxPooling  (None, 12, 128)          0
#  1D)
#
#  flatten_2 (Flatten)         (None, 1536)              0
#
#  dense_14 (Dense)            (None, 256)               393472
#
#  dropout_232 (Dropout)       (None, 256)               0
#
#  dense_15 (Dense)            (None, 64)                16448
#
#  dropout_233 (Dropout)       (None, 64)                0
#
#  dense_16 (Dense)            (None, 128)               8320
#
#  dropout_234 (Dropout)       (None, 128)               0
#
#  dense_17 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 981,213
# Trainable params: 981,213
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NNTest/32!
# Running setup of directory for experiment NNTest/32
# Compiling model
# Fitting model
# 6/6 [==============================] - 3s 227ms/step - loss: 1.6100 - accuracy: 0.1765 - val_loss: 1.5977 - val_accuracy: 0.3438 - time: 2.8559
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_3 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_3 (Embedding)     (None, 130, 300)          15600
#
#  conv1d_9 (Conv1D)           (None, 127, 128)          153728
#
#  max_pooling1d_9 (MaxPooling  (None, 63, 128)          0
#  1D)
#  conv1d_10 (Conv1D)          (None, 58, 256)           196864
#
#  max_pooling1d_10 (MaxPoolin  (None, 29, 256)          0
#  g1D)
#
#  conv1d_11 (Conv1D)          (None, 24, 128)           196736
#
#  max_pooling1d_11 (MaxPoolin  (None, 12, 128)          0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 1536)              0
#
#  dense_18 (Dense)            (None, 256)               393472
#
#  dropout_235 (Dropout)       (None, 256)               0
#
#  dense_19 (Dense)            (None, 64)                16448
#
#  dropout_236 (Dropout)       (None, 64)                0
#
#  dense_20 (Dense)            (None, 128)               8320
#
#  dropout_237 (Dropout)       (None, 128)               0
#
#  dense_21 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 981,813
# Trainable params: 981,813
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NNTest/33!
# Running setup of directory for experiment NNTest/33
# Compiling model
# Fitting model
# 6/6 [==============================] - 3s 226ms/step - loss: 1.6082 - accuracy: 0.2424 - val_loss: 1.5739 - val_accuracy: 0.2031 - time: 2.7846
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_4 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_4 (Embedding)     (None, 130, 300)          15600
#
#  conv1d_12 (Conv1D)          (None, 127, 128)          153728
#
#  max_pooling1d_12 (MaxPoolin  (None, 63, 128)          0
#  g1D)
#
#  conv1d_13 (Conv1D)          (None, 58, 256)           196864
#
#  max_pooling1d_13 (MaxPoolin  (None, 29, 256)          0
#  g1D)
#
#  conv1d_14 (Conv1D)          (None, 24, 128)           196736
#
#  max_pooling1d_14 (MaxPoolin  (None, 12, 128)          0
#  g1D)
#
#  flatten_4 (Flatten)         (None, 1536)              0
#
#  dense_22 (Dense)            (None, 256)               393472
#
#  dropout_238 (Dropout)       (None, 256)               0
#
#  dense_23 (Dense)            (None, 64)                16448
#
#  dropout_239 (Dropout)       (None, 64)                0
#
#  dense_24 (Dense)            (None, 128)               8320
#
#  dropout_240 (Dropout)       (None, 128)               0
#
#  dense_25 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 981,813
# Trainable params: 981,813
# Non-trainable params: 0
# _________________________________________________________________
# ...
# Compiling model
# Fitting model
# 6/6 [==============================] - 2s 129ms/step - loss: 1.6633 - accuracy: 0.2071 - val_loss: 1.6216 - val_accuracy: 0.2188 - time: 1.8564
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_25 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_24 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_24 (Embedding)    (None, 130, 300)          15600
#
#  flatten_14 (Flatten)        (None, 39000)             0
#
#  dense_92 (Dense)            (None, 64)                2496064
#
#  dropout_288 (Dropout)       (None, 64)                0
#
#  dense_93 (Dense)            (None, 32)                2080
#
#  dropout_289 (Dropout)       (None, 32)                0
#
#  dense_94 (Dense)            (None, 64)                2112
#
#  dropout_290 (Dropout)       (None, 64)                0
#
#  dense_95 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 2,516,181
# Trainable params: 2,516,181
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NNTest/54!
# Running setup of directory for experiment NNTest/54
# Compiling model
# Fitting model
# 6/6 [==============================] - 2s 151ms/step - loss: 1.6052 - accuracy: 0.2094 - val_loss: 1.5849 - val_accuracy: 0.2188 - time: 1.9550
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_26 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_25 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_25 (Embedding)    (None, 130, 50)           2500
#
#  flatten_15 (Flatten)        (None, 6500)              0
#
#  dense_96 (Dense)            (None, 64)                416064
#
#  dropout_291 (Dropout)       (None, 64)                0
#
#  dense_97 (Dense)            (None, 32)                2080
#
#  dropout_292 (Dropout)       (None, 32)                0
#
#  dense_98 (Dense)            (None, 64)                2112
#
#  dropout_293 (Dropout)       (None, 64)                0
#
#  dense_99 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 423,081
# Trainable params: 420,581
# Non-trainable params: 2,500
# _________________________________________________________________
# Creating new experiment summarization for NNTest/55!
# Running setup of directory for experiment NNTest/55
# Compiling model
# Fitting model
# 6/6 [==============================] - 2s 116ms/step - loss: 1.6149 - accuracy: 0.2188 - val_loss: 1.5931 - val_accuracy: 0.1875 - time: 1.6680
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_26 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_26 (Embedding)    (None, 130, 150)          7500
#
#  flatten_16 (Flatten)        (None, 19500)             0
#
#  dense_100 (Dense)           (None, 64)                1248064
#
#  dropout_294 (Dropout)       (None, 64)                0
#
#  dense_101 (Dense)           (None, 32)                2080
#
#  dropout_295 (Dropout)       (None, 32)                0
#
#  dense_102 (Dense)           (None, 64)                2112
#
#  dropout_296 (Dropout)       (None, 64)                0
#
#  dense_103 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 1,260,081
# Trainable params: 1,252,581
# Non-trainable params: 7,500
# _________________________________________________________________
# Creating new experiment summarization for NNTest/56!
# Running setup of directory for experiment NNTest/56
# Compiling model
# Fitting model
# 6/6 [==============================] - 2s 99ms/step - loss: 1.6343 - accuracy: 0.2141 - val_loss: 1.5637 - val_accuracy: 0.2969 - time: 1.6032
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_28 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_27 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_27 (Embedding)    (None, 130, 300)          15000
#
#  flatten_17 (Flatten)        (None, 39000)             0
#
#  dense_104 (Dense)           (None, 64)                2496064
#
#  dropout_297 (Dropout)       (None, 64)                0
#
#  dense_105 (Dense)           (None, 32)                2080
#
#  dropout_298 (Dropout)       (None, 32)                0
#
#  dense_106 (Dense)           (None, 64)                2112
#
#  dropout_299 (Dropout)       (None, 64)                0
#
#  dense_107 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 2,515,581
# Trainable params: 2,500,581
# Non-trainable params: 15,000
# _________________________________________________________________
# Creating new experiment summarization for NNTest/57!
# Running setup of directory for experiment NNTest/57
# Compiling model
# Fitting model
# 6/6 [==============================] - 1s 114ms/step - loss: 1.6773 - accuracy: 0.2188 - val_loss: 1.5652 - val_accuracy: 0.3750 - time: 1.4682
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_29 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_28 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_28 (Embedding)    (None, 130, 300)          15600
#
#  flatten_18 (Flatten)        (None, 39000)             0
#
#  dense_108 (Dense)           (None, 64)                2496064
#
#  dropout_300 (Dropout)       (None, 64)                0
#
#  dense_109 (Dense)           (None, 32)                2080
#  dropout_301 (Dropout)       (None, 32)                0
#
#  dense_110 (Dense)           (None, 64)                2112
#
#  dropout_302 (Dropout)       (None, 64)                0
#
#  dense_111 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 2,516,181
# Trainable params: 2,500,581
# Non-trainable params: 15,600
# _________________________________________________________________
# Creating new experiment summarization for NNTest/58!
# Running setup of directory for experiment NNTest/58
# Compiling model
# Fitting model
# 6/6 [==============================] - 2s 154ms/step - loss: 1.6768 - accuracy: 0.2329 - val_loss: 1.6013 - val_accuracy: 0.1875 - time: 1.8204
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=1LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fe600e699a0>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fe600547160>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_30 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_29 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_29 (Embedding)    (None, 130, 300)          15600
#
#  flatten_19 (Flatten)        (None, 39000)             0
#
#  dense_112 (Dense)           (None, 64)                2496064
#
#  dropout_303 (Dropout)       (None, 64)                0
#
#  dense_113 (Dense)           (None, 32)                2080
#
#  dropout_304 (Dropout)       (None, 32)                0
#
#  dense_114 (Dense)           (None, 64)                2112
#
#  dropout_305 (Dropout)       (None, 64)                0
#
#  dense_115 (Dense)           (None, 5)                 325
#
# =================================================================
# Total params: 2,516,181
# Trainable params: 2,500,581
# Non-trainable params: 15,600
# _________________________________________________________________
# Creating new experiment summarization for NNTest/59!
# Running setup of directory for experiment NNTest/59
# Compiling model
# Fitting model
# 6/6 [==============================] - 2s 133ms/step - loss: 1.6015 - accuracy: 0.2165 - val_loss: 1.5933 - val_accuracy: 0.2969 - time: 1.7928
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# End of NN tests!
