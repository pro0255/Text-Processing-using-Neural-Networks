# %%
import os
import sys

def adding_module_path():
    module_path = os.path.abspath(os.path.sep.join([".."]*5))

    if module_path not in sys.path:
        sys.path.append(module_path)

adding_module_path()

from src.config.run_prep import run_prep
from src.utils.log_juypter import add_experiment_jupyter_logger

run_prep()
add_experiment_jupyter_logger(os.getcwd())
# Out:
# Running preperation of packages
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# <_io.TextIOWrapper name='/home/usp/pro0255/diploma/jupyters/experiments/nn/no_transformer/310combs/jupyter_log.txt' mode='a+' encoding='UTF-8'>

# %% [markdown]
# ### Import of ExperimentTypes

# %%
from src.experiments.experiment_scripts.types.experiment_types import ExperimentType

# %% [markdown]
# #### All experiments can be shown

# %%
list(ExperimentType)
# Out:
# [<ExperimentType.TrainableTransformer: 'Learning'>,
#  <ExperimentType.PoolingStrategyTransformer: 'PoolingStrategyTransformer'>,
#  <ExperimentType.OutputSequenceLengthTransformer: 'OutputSequenceLength'>,
#  <ExperimentType.LearningRateTransformer: 'LearningRateTransformer'>,
#  <ExperimentType.LabelSizeTransformer: 'LabelSizeLabelSizeTransformer'>,
#  <ExperimentType.PreprocessingType: 'PreprocessingType'>,
#  <ExperimentType.TransformerType: 'TransformerType'>,
#  <ExperimentType.PreprocessingTransformer: 'PreprocessingTransformer'>,
#  <ExperimentType.Transformer310Combinations: 'Transformer310Combinations'>,
#  <ExperimentType.Transformer5SentencesCombinations: 'Transformer5SentencesCombinations'>,
#  <ExperimentType.NumberOfAuthorsNN: 'NumberOfAuthorsNN'>,
#  <ExperimentType.NumberOfSentencesNN: 'NumberOfSentencesNN'>,
#  <ExperimentType.NN310Combinations: 'NN310Combinations'>,
#  <ExperimentType.NN5SentencesCombinations: 'NN5SentencesCombinations'>,
#  <ExperimentType.EmbeddingSizeNN: 'EmbeddingSizeNN'>,
#  <ExperimentType.Classic: 'Classic'>,
#  <ExperimentType.ClassicLogisticRegressionLabelSize: 'ClassicLogisticRegressionLabelSize'>,
#  <ExperimentType.ClassicLogisticRegressionPreprocessing: 'ClassicLogisticRegressionPreprocessing'>,
#  <ExperimentType.Classic310Combinations: 'Classic310Combinations'>,
#  <ExperimentType.Classic5SentencesCombinations: 'Classic5SentencesCombinations'>,
#  <ExperimentType.TransformerTest: 'TransformerTest'>,
#  <ExperimentType.NNTest: 'NNTest'>,
#  <ExperimentType.ClassicTest: 'ClassicTest'>]

# %%
from src.experiments.experiment_scripts.experiment_configurations.config import experiment_config
# Out:
# 2022-04-19 16:01:06.222500: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory

# %%
list(experiment_config.keys())
# Out:
# [<ExperimentType.TrainableTransformer: 'Learning'>,
#  <ExperimentType.PreprocessingTransformer: 'PreprocessingTransformer'>,
#  <ExperimentType.PoolingStrategyTransformer: 'PoolingStrategyTransformer'>,
#  <ExperimentType.OutputSequenceLengthTransformer: 'OutputSequenceLength'>,
#  <ExperimentType.LearningRateTransformer: 'LearningRateTransformer'>,
#  <ExperimentType.TransformerType: 'TransformerType'>,
#  <ExperimentType.LabelSizeTransformer: 'LabelSizeLabelSizeTransformer'>,
#  <ExperimentType.NumberOfAuthorsNN: 'NumberOfAuthorsNN'>,
#  <ExperimentType.EmbeddingSizeNN: 'EmbeddingSizeNN'>,
#  <ExperimentType.Classic: 'Classic'>,
#  <ExperimentType.ClassicLogisticRegressionLabelSize: 'ClassicLogisticRegressionLabelSize'>,
#  <ExperimentType.ClassicLogisticRegressionPreprocessing: 'ClassicLogisticRegressionPreprocessing'>,
#  <ExperimentType.Classic5SentencesCombinations: 'Classic5SentencesCombinations'>,
#  <ExperimentType.Classic310Combinations: 'Classic310Combinations'>,
#  <ExperimentType.NN310Combinations: 'NN310Combinations'>,
#  <ExperimentType.NN5SentencesCombinations: 'NN5SentencesCombinations'>,
#  <ExperimentType.Transformer310Combinations: 'Transformer310Combinations'>,
#  <ExperimentType.Transformer5SentencesCombinations: 'Transformer5SentencesCombinations'>]

# %%
from src.experiments.experiment_scripts.neural_nets.no_transformer.neural_net_runner import NNRunner

# %%
experiment = NNRunner(experiment_type=ExperimentType.NN310Combinations, config_dict=experiment_config)
# Out:
# [10]
# Loading embeddding
# Already loaded model=glove-wiki-gigaword-300
# Already loaded model=word2vec-google-news-300
# Embedding dictionaries loaded..
# Loaded configuration [<ExperimentGeneratorPart.DatasetGenerator: 'DatasetGenerator'>, <ExperimentGeneratorPart.ExperimentConfiguration: 'ExperimentConfiguration'>, <ExperimentGeneratorPart.ExperimentArchitecture: 'ExperimentArchitecture'>]

# %%
experiment.run()
# Out:
# Loading dataset from=/home/usp/pro0255/diploma/data/gutenberg/5Authors/Sentence3/data.csv
# Creating shorting method with min = 3
# Creating lemma method with instance <WordNetLemmatizer>
# Specified type CaseInterpunction
# Train (54187,)
# Valid (9563,)
# Test (11250,)
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7ff49197a430>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7ff1cc764730>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization (TextVec  (None, 100)              0
#  torization)
#
#  embedding (Embedding)       (None, 100, 50)           2597100
#
#  conv1d (Conv1D)             (None, 97, 128)           25728
#
#  max_pooling1d (MaxPooling1D  (None, 48, 128)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 43, 256)           196864
#
#  max_pooling1d_1 (MaxPooling  (None, 21, 256)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 16, 128)           196736
#
#  max_pooling1d_2 (MaxPooling  (None, 8, 128)           0
#  1D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,304,241
# Trainable params: 3,304,241
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NN310Combinations/0!
# Running setup of directory for experiment NN310Combinations/0
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 77s 89ms/step - loss: 1.1998 - accuracy: 0.4536 - val_loss: 0.8066 - val_accuracy: 0.6773 - time: 76.4001
# Epoch 2/10
# 847/847 [==============================] - 73s 86ms/step - loss: 0.5595 - accuracy: 0.7965 - val_loss: 0.5194 - val_accuracy: 0.8208 - time: 149.2722
# Epoch 3/10
# 847/847 [==============================] - 71s 84ms/step - loss: 0.2928 - accuracy: 0.9007 - val_loss: 0.5525 - val_accuracy: 0.8347 - time: 220.7629
# Epoch 4/10
# 847/847 [==============================] - 78s 93ms/step - loss: 0.1887 - accuracy: 0.9384 - val_loss: 0.5749 - val_accuracy: 0.8377 - time: 299.2447
# Epoch 5/10
# 847/847 [==============================] - 109s 129ms/step - loss: 0.1365 - accuracy: 0.9555 - val_loss: 0.6398 - val_accuracy: 0.8421 - time: 408.6896
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7ff49197a430>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7ff1cc764730>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_1 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_1 (Embedding)     (None, 100, 150)          7791300
#
#  conv1d_3 (Conv1D)           (None, 97, 128)           76928
#
#  max_pooling1d_3 (MaxPooling  (None, 48, 128)          0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 43, 256)           196864
#
#  max_pooling1d_4 (MaxPooling  (None, 21, 256)          0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 16, 128)           196736
#
#  max_pooling1d_5 (MaxPooling  (None, 8, 128)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 256)               262400
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 64)                16448
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 128)               8320
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 8,549,641
# Trainable params: 8,549,641
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NN310Combinations/1!
# Running setup of directory for experiment NN310Combinations/1
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 162s 190ms/step - loss: 1.2749 - accuracy: 0.4833 - val_loss: 1.0247 - val_accuracy: 0.5634 - time: 161.7252
# Epoch 2/10
# 847/847 [==============================] - 173s 205ms/step - loss: 0.6608 - accuracy: 0.7491 - val_loss: 0.5340 - val_accuracy: 0.8123 - time: 335.4083
# Epoch 3/10
# 847/847 [==============================] - 147s 174ms/step - loss: 0.3064 - accuracy: 0.8974 - val_loss: 0.5733 - val_accuracy: 0.8221 - time: 483.1123
# Epoch 4/10
# 847/847 [==============================] - 148s 175ms/step - loss: 0.1808 - accuracy: 0.9403 - val_loss: 0.6396 - val_accuracy: 0.8217 - time: 631.5948
# Epoch 5/10
# 847/847 [==============================] - 146s 172ms/step - loss: 0.1268 - accuracy: 0.9584 - val_loss: 0.6721 - val_accuracy: 0.8325 - time: 777.6830
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7ff49197a430>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7ff1cc764730>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_2 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_2 (Embedding)     (None, 100, 200)          10388400
#
#  conv1d_6 (Conv1D)           (None, 97, 128)           102528
#
#  max_pooling1d_6 (MaxPooling  (None, 48, 128)          0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 43, 256)           196864
#
#  max_pooling1d_7 (MaxPooling  (None, 21, 256)          0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 16, 128)           196736
#
#  max_pooling1d_8 (MaxPooling  (None, 8, 128)           0
#  1D)
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 256)               262400
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 64)                16448
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 128)               8320
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 11,172,341
# Trainable params: 11,172,341
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NN310Combinations/2!
# Running setup of directory for experiment NN310Combinations/2
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 224s 263ms/step - loss: 1.1636 - accuracy: 0.5463 - val_loss: 0.7520 - val_accuracy: 0.7102 - time: 223.6466
# Epoch 2/10
# 847/847 [==============================] - 217s 256ms/step - loss: 0.5512 - accuracy: 0.8011 - val_loss: 0.5445 - val_accuracy: 0.8143 - time: 441.0673
# Epoch 3/10
# 847/847 [==============================] - 215s 254ms/step - loss: 0.2895 - accuracy: 0.9017 - val_loss: 0.5798 - val_accuracy: 0.8287 - time: 656.8704
# Epoch 4/10
# 847/847 [==============================] - 245s 290ms/step - loss: 0.1794 - accuracy: 0.9398 - val_loss: 0.7016 - val_accuracy: 0.8240 - time: 902.2341
# Epoch 5/10
# 847/847 [==============================] - 208s 245ms/step - loss: 0.1294 - accuracy: 0.9585 - val_loss: 0.6784 - val_accuracy: 0.8384 - time: 1126.4724
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7ff49197a430>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7ff1cc764730>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_3 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_3 (Embedding)     (None, 100, 300)          15583200
#
#  conv1d_9 (Conv1D)           (None, 97, 128)           153728
#
#  max_pooling1d_9 (MaxPooling  (None, 48, 128)          0
#  1D)
#
#  conv1d_10 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_10 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_11 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_11 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 1024)              0
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 64)                16448
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 128)               8320
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 16,418,341
# Trainable params: 16,418,341
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NN310Combinations/3!
# Running setup of directory for experiment NN310Combinations/3
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 324s 380ms/step - loss: 1.0670 - accuracy: 0.5922 - val_loss: 0.7216 - val_accuracy: 0.7261 - time: 323.2019
# Epoch 2/10
# 847/847 [==============================] - 320s 377ms/step - loss: 0.5150 - accuracy: 0.8144 - val_loss: 0.5343 - val_accuracy: 0.8142 - time: 703.2388
# Epoch 3/10
# 847/847 [==============================] - 288s 340ms/step - loss: 0.2749 - accuracy: 0.9057 - val_loss: 0.5613 - val_accuracy: 0.8198 - time: 991.8586
# Epoch 4/10
# 847/847 [==============================] - 272s 322ms/step - loss: 0.1731 - accuracy: 0.9420 - val_loss: 0.7070 - val_accuracy: 0.8199 - time: 1264.3330
# Epoch 5/10
# 847/847 [==============================] - 273s 322ms/step - loss: 0.1310 - accuracy: 0.9569 - val_loss: 0.7156 - val_accuracy: 0.8243 - time: 1537.3437
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7ff49197a430>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7ff1cc764730>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_4 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_4 (Embedding)     (None, 100, 300)          15583200
#
#  conv1d_12 (Conv1D)          (None, 97, 128)           153728
#
#  max_pooling1d_12 (MaxPoolin  (None, 48, 128)          0
#  g1D)
#
#  conv1d_13 (Conv1D)          (None, 43, 256)           196864
#
#  max_pooling1d_13 (MaxPoolin  (None, 21, 256)          0
#  g1D)
#
#  conv1d_14 (Conv1D)          (None, 16, 128)           196736
#
#  max_pooling1d_14 (MaxPoolin  (None, 8, 128)           0
#  g1D)
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_16 (Dense)            (None, 256)               262400
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 64)                16448
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_18 (Dense)            (None, 128)               8320
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 16,418,341
# Trainable params: 16,418,341
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NN310Combinations/4!
# Running setup of directory for experiment NN310Combinations/4
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 266s 313ms/step - loss: 1.4275 - accuracy: 0.3978 - val_loss: 1.0104 - val_accuracy: 0.5742 - time: 265.7614
# Epoch 2/10
# 847/847 [==============================] - 263s 311ms/step - loss: 0.7781 - accuracy: 0.7007 - val_loss: 0.6481 - val_accuracy: 0.7625 - time: 529.4708
# Epoch 3/10
# 847/847 [==============================] - 303s 358ms/step - loss: 0.3946 - accuracy: 0.8629 - val_loss: 0.6339 - val_accuracy: 0.7987 - time: 832.2435
# Epoch 4/10
# 847/847 [==============================] - 318s 376ms/step - loss: 0.2174 - accuracy: 0.9272 - val_loss: 0.6007 - val_accuracy: 0.8244 - time: 1150.5735
# Epoch 5/10
# 847/847 [==============================] - 319s 377ms/step - loss: 0.1444 - accuracy: 0.9524 - val_loss: 0.6682 - val_accuracy: 0.8281 - time: 1470.4527
# Epoch 6/10
# 847/847 [==============================] - 320s 378ms/step - loss: 0.1069 - accuracy: 0.9649 - val_loss: 0.7041 - val_accuracy: 0.8321 - time: 1790.3873
# Epoch 7/10
# 847/847 [==============================] - 323s 381ms/step - loss: 0.0860 - accuracy: 0.9709 - val_loss: 0.8102 - val_accuracy: 0.8278 - time: 2112.8181
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7ff49197a430>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7ff1cc764730>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_5 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_5 (Embedding)     (None, 100, 50)           2597100
#
#  flatten_5 (Flatten)         (None, 5000)              0
#
#  dense_20 (Dense)            (None, 64)                320064
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_21 (Dense)            (None, 32)                2080
#
#  dropout_16 (Dropout)        (None, 32)                0
#
#  dense_22 (Dense)            (None, 64)                2112
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_23 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 2,921,681
# Trainable params: 2,921,681
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NN310Combinations/5!
# Running setup of directory for experiment NN310Combinations/5
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 52s 59ms/step - loss: 1.0021 - accuracy: 0.6336 - val_loss: 0.5754 - val_accuracy: 0.7955 - time: 51.3114
# Epoch 2/10
# 847/847 [==============================] - 48s 57ms/step - loss: 0.3683 - accuracy: 0.8769 - val_loss: 0.5126 - val_accuracy: 0.8334 - time: 100.0332
# Epoch 3/10
# 847/847 [==============================] - 49s 57ms/step - loss: 0.1829 - accuracy: 0.9403 - val_loss: 0.6089 - val_accuracy: 0.8315 - time: 182.3059
# Epoch 4/10
# 847/847 [==============================] - 49s 58ms/step - loss: 0.1168 - accuracy: 0.9615 - val_loss: 0.7515 - val_accuracy: 0.8299 - time: 231.3158
# Epoch 5/10
# 847/847 [==============================] - 48s 57ms/step - loss: 0.0890 - accuracy: 0.9701 - val_loss: 0.8313 - val_accuracy: 0.8275 - time: 279.7370
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7ff49197a430>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7ff1cc764730>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_6 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_6 (Embedding)     (None, 100, 150)          7791300
#
#  flatten_6 (Flatten)         (None, 15000)             0
#
#  dense_24 (Dense)            (None, 64)                960064
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_26 (Dense)            (None, 64)                2112
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_27 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 8,755,881
# Trainable params: 8,755,881
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NN310Combinations/6!
# Running setup of directory for experiment NN310Combinations/6
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 100s 116ms/step - loss: 1.0664 - accuracy: 0.5913 - val_loss: 0.7397 - val_accuracy: 0.7154 - time: 99.3604
# Epoch 2/10
# 847/847 [==============================] - 99s 117ms/step - loss: 0.4792 - accuracy: 0.8236 - val_loss: 0.5834 - val_accuracy: 0.7980 - time: 198.6968
# Epoch 3/10
# 847/847 [==============================] - 100s 119ms/step - loss: 0.2156 - accuracy: 0.9294 - val_loss: 0.6015 - val_accuracy: 0.8196 - time: 342.3431
# Epoch 4/10
# 847/847 [==============================] - 99s 117ms/step - loss: 0.1209 - accuracy: 0.9613 - val_loss: 0.7322 - val_accuracy: 0.8128 - time: 441.4712
# Epoch 5/10
# 847/847 [==============================] - 94s 111ms/step - loss: 0.0894 - accuracy: 0.9712 - val_loss: 0.7645 - val_accuracy: 0.8225 - time: 535.8802
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7ff49197a430>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7ff1cc764730>
# Model: "Dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_7 (TextV  (None, 100)              0
#  ectorization)
#
#  embedding_7 (Embedding)     (None, 100, 200)          10388400
#
#  flatten_7 (Flatten)         (None, 20000)             0
#
#  dense_28 (Dense)            (None, 64)                1280064
#
#  dropout_21 (Dropout)        (None, 64)                0
#
#  dense_29 (Dense)            (None, 32)                2080
#
#  dropout_22 (Dropout)        (None, 32)                0
#
#  dense_30 (Dense)            (None, 64)                2112
#
#  dropout_23 (Dropout)        (None, 64)                0
#
#  dense_31 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 11,672,981
# Trainable params: 11,672,981
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NN310Combinations/7!
# Running setup of directory for experiment NN310Combinations/7
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 184s 214ms/step - loss: 1.0654 - accuracy: 0.5933 - val_loss: 0.6857 - val_accuracy: 0.7485 - time: 183.2727
# Epoch 2/10
# 847/847 [==============================] - 182s 215ms/step - loss: 0.4367 - accuracy: 0.8459 - val_loss: 0.5421 - val_accuracy: 0.8169 - time: 365.5473
# Epoch 3/10
# 688/847 [=======================>......] - ETA: 27s - loss: 0.2045 - accuracy: 0.9325
