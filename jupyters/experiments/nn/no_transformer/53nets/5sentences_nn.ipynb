# %%
import os
import sys

def adding_module_path():
    module_path = os.path.abspath(os.path.sep.join([".."]*4))

    if module_path not in sys.path:
        sys.path.append(module_path)

adding_module_path()

from src.config.run_prep import run_prep
from src.utils.log_juypter import add_experiment_jupyter_logger

run_prep()
add_experiment_jupyter_logger(os.getcwd())
# Out:
# Running preperation of packages
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/usp/pro0255/diploma/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# <_io.TextIOWrapper name='/home/usp/pro0255/diploma/jupyters/experiments/nn/53nets/jupyter_log.txt' mode='a+' encoding='UTF-8'>

# %%
from src.experiments.experiment_scripts.types.experiment_types import ExperimentType

# %%
list(ExperimentType)
# Out:
# [<ExperimentType.TrainableTransformer: 'Learning'>,
#  <ExperimentType.PoolingStrategyTransformer: 'PoolingStrategyTransformer'>,
#  <ExperimentType.OutputSequenceLengthTransformer: 'OutputSequenceLength'>,
#  <ExperimentType.LearningRateTransformer: 'LearningRateTransformer'>,
#  <ExperimentType.LabelSize: 'LabelSize'>,
#  <ExperimentType.PreprocessingType: 'PreprocessingType'>,
#  <ExperimentType.TransformerType: 'TransformerType'>,
#  <ExperimentType.NumberOfAuthorsNN: 'NumberOfAuthorsNN'>,
#  <ExperimentType.NumberOfSentencesNN: 'NumberOfSentencesNN'>,
#  <ExperimentType.Classic: 'Classic'>]

# %%
from src.experiments.experiment_scripts.experiment_configurations.config import experiment_config
# Out:
# 2022-04-12 00:42:08.819555: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# [5]
# [5]
# [5]
# [5]
# [10]
# [5]
# [10]
# Loading embeddding
# Already loaded model=glove-wiki-gigaword-300
# Already loaded model=word2vec-google-news-300
# Embedding dictionaries loaded..

# %%
from src.experiments.experiment_scripts.neural_nets.no_transformer.neural_net_runner import NNRunner

# %%
experiment = NNRunner(experiment_type=ExperimentType.NN5SentencesCombinations, config_dict=experiment_config)
# Out:
# ExperimentType.NumberOfAuthorsNN

# %%
experiment.run()
# Out:
# Loading dataset from=/home/usp/pro0255/diploma/data/gutenberg/5Authors/Sentence3/data.csv
# Creating shorting method with min = 3
# Creating lemma method with instance <WordNetLemmatizer>
# Specified type CaseInterpunction
# Train (54187,)
# Valid (9563,)
# Test (11250,)
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization (TextVec  (None, 130)              0
#  torization)
#
#  embedding (Embedding)       (None, 130, 50)           750000
#
#  conv1d (Conv1D)             (None, 127, 128)          25728
#
#  max_pooling1d (MaxPooling1D  (None, 63, 128)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 58, 256)           196864
#
#  max_pooling1d_1 (MaxPooling  (None, 29, 256)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 24, 128)           196736
#
#  max_pooling1d_2 (MaxPooling  (None, 12, 128)          0
#  1D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 256)               393472
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1,588,213
# Trainable params: 1,588,213
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/1!
# Running setup of directory for experiment NumberOfAuthorsNN/1
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 72s 83ms/step - loss: 1.2463 - accuracy: 0.4123 - val_loss: 0.8857 - val_accuracy: 0.6168 - time: 71.8808
# Epoch 2/10
# 847/847 [==============================] - 70s 82ms/step - loss: 0.7068 - accuracy: 0.7039 - val_loss: 0.5767 - val_accuracy: 0.7804 - time: 141.4588
# Epoch 3/10
# 847/847 [==============================] - 69s 81ms/step - loss: 0.4278 - accuracy: 0.8479 - val_loss: 0.5630 - val_accuracy: 0.8085 - time: 210.4887
# Epoch 4/10
# 847/847 [==============================] - 68s 81ms/step - loss: 0.2987 - accuracy: 0.8977 - val_loss: 0.6382 - val_accuracy: 0.8087 - time: 278.7430
# Epoch 5/10
# 847/847 [==============================] - 69s 81ms/step - loss: 0.2237 - accuracy: 0.9255 - val_loss: 0.6092 - val_accuracy: 0.8309 - time: 347.5635
# Epoch 6/10
# 847/847 [==============================] - 69s 81ms/step - loss: 0.1737 - accuracy: 0.9422 - val_loss: 0.6238 - val_accuracy: 0.8211 - time: 416.5306
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_1 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_1 (Embedding)     (None, 130, 150)          2250000
#
#  conv1d_3 (Conv1D)           (None, 127, 128)          76928
#
#  max_pooling1d_3 (MaxPooling  (None, 63, 128)          0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 58, 256)           196864
#
#  max_pooling1d_4 (MaxPooling  (None, 29, 256)          0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 24, 128)           196736
#
#  max_pooling1d_5 (MaxPooling  (None, 12, 128)          0
#  1D)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
#  dense_4 (Dense)             (None, 256)               393472
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 64)                16448
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 128)               8320
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,139,413
# Trainable params: 3,139,413
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/2!
# Running setup of directory for experiment NumberOfAuthorsNN/2
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 92s 108ms/step - loss: 1.4582 - accuracy: 0.3854 - val_loss: 1.1318 - val_accuracy: 0.5166 - time: 92.1423
# Epoch 2/10
# 847/847 [==============================] - 94s 111ms/step - loss: 0.8612 - accuracy: 0.6546 - val_loss: 0.7199 - val_accuracy: 0.7261 - time: 186.2846
# Epoch 3/10
# 847/847 [==============================] - 92s 109ms/step - loss: 0.5250 - accuracy: 0.8108 - val_loss: 0.6297 - val_accuracy: 0.7839 - time: 278.2857
# Epoch 4/10
# 847/847 [==============================] - 98s 115ms/step - loss: 0.3193 - accuracy: 0.8922 - val_loss: 0.5760 - val_accuracy: 0.8208 - time: 376.0508
# Epoch 5/10
# 847/847 [==============================] - 126s 148ms/step - loss: 0.2103 - accuracy: 0.9304 - val_loss: 0.6918 - val_accuracy: 0.8191 - time: 545.8075
# Epoch 6/10
# 847/847 [==============================] - 125s 147ms/step - loss: 0.1583 - accuracy: 0.9484 - val_loss: 0.7443 - val_accuracy: 0.8367 - time: 670.5212
# Epoch 7/10
# 847/847 [==============================] - 125s 147ms/step - loss: 0.1289 - accuracy: 0.9571 - val_loss: 0.8165 - val_accuracy: 0.8275 - time: 795.0595
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_2 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_2 (Embedding)     (None, 130, 300)          4500000
#
#  conv1d_6 (Conv1D)           (None, 127, 128)          153728
#
#  max_pooling1d_6 (MaxPooling  (None, 63, 128)          0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 58, 256)           196864
#
#  max_pooling1d_7 (MaxPooling  (None, 29, 256)          0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 24, 128)           196736
#
#  max_pooling1d_8 (MaxPooling  (None, 12, 128)          0
#  1D)
#
#  flatten_2 (Flatten)         (None, 1536)              0
#
#  dense_8 (Dense)             (None, 256)               393472
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 64)                16448
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 128)               8320
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 5,466,213
# Trainable params: 5,466,213
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/3!
# Running setup of directory for experiment NumberOfAuthorsNN/3
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 163s 191ms/step - loss: 1.3029 - accuracy: 0.4737 - val_loss: 1.1255 - val_accuracy: 0.5344 - time: 163.1316
# Epoch 2/10
# 847/847 [==============================] - 158s 187ms/step - loss: 0.8504 - accuracy: 0.6607 - val_loss: 0.6600 - val_accuracy: 0.7651 - time: 321.6608
# Epoch 3/10
# 847/847 [==============================] - 160s 189ms/step - loss: 0.4507 - accuracy: 0.8449 - val_loss: 0.5347 - val_accuracy: 0.8161 - time: 481.3212
# Epoch 4/10
# 847/847 [==============================] - 159s 188ms/step - loss: 0.2855 - accuracy: 0.9035 - val_loss: 0.6146 - val_accuracy: 0.8188 - time: 640.6934
# Epoch 5/10
# 847/847 [==============================] - 157s 186ms/step - loss: 0.2091 - accuracy: 0.9307 - val_loss: 0.6348 - val_accuracy: 0.8277 - time: 798.0489
# Epoch 6/10
# 847/847 [==============================] - 158s 187ms/step - loss: 0.1665 - accuracy: 0.9464 - val_loss: 0.6061 - val_accuracy: 0.8342 - time: 956.0152
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_3 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_3 (Embedding)     (None, 130, 300)          4500600
#
#  conv1d_9 (Conv1D)           (None, 127, 128)          153728
#
#  max_pooling1d_9 (MaxPooling  (None, 63, 128)          0
#  1D)
#
#  conv1d_10 (Conv1D)          (None, 58, 256)           196864
#
#  max_pooling1d_10 (MaxPoolin  (None, 29, 256)          0
#  g1D)
#
#  conv1d_11 (Conv1D)          (None, 24, 128)           196736
#
#  max_pooling1d_11 (MaxPoolin  (None, 12, 128)          0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 1536)              0
#
#  dense_12 (Dense)            (None, 256)               393472
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 64)                16448
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 128)               8320
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 5,466,813
# Trainable params: 5,466,813
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/4!
# Running setup of directory for experiment NumberOfAuthorsNN/4
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 164s 191ms/step - loss: 1.0730 - accuracy: 0.5913 - val_loss: 0.7450 - val_accuracy: 0.7160 - time: 163.5967
# Epoch 2/10
# 847/847 [==============================] - 159s 188ms/step - loss: 0.5504 - accuracy: 0.8022 - val_loss: 0.5799 - val_accuracy: 0.8009 - time: 362.3204
# Epoch 3/10
# 847/847 [==============================] - 154s 182ms/step - loss: 0.3392 - accuracy: 0.8825 - val_loss: 0.5431 - val_accuracy: 0.8214 - time: 516.3350
# Epoch 4/10
# 847/847 [==============================] - 188s 222ms/step - loss: 0.2364 - accuracy: 0.9209 - val_loss: 0.6022 - val_accuracy: 0.8133 - time: 704.2699
# Epoch 5/10
# 847/847 [==============================] - 156s 184ms/step - loss: 0.1818 - accuracy: 0.9413 - val_loss: 0.6329 - val_accuracy: 0.8153 - time: 860.4037
# Epoch 6/10
# 847/847 [==============================] - 188s 223ms/step - loss: 0.1412 - accuracy: 0.9532 - val_loss: 0.7508 - val_accuracy: 0.8134 - time: 1048.8640
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_4 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_4 (Embedding)     (None, 130, 300)          4500600
#
#  conv1d_12 (Conv1D)          (None, 127, 128)          153728
#
#  max_pooling1d_12 (MaxPoolin  (None, 63, 128)          0
#  g1D)
#
#  conv1d_13 (Conv1D)          (None, 58, 256)           196864
#
#  max_pooling1d_13 (MaxPoolin  (None, 29, 256)          0
#  g1D)
#
#  conv1d_14 (Conv1D)          (None, 24, 128)           196736
#
#  max_pooling1d_14 (MaxPoolin  (None, 12, 128)          0
#  g1D)
#
#  flatten_4 (Flatten)         (None, 1536)              0
#
#  dense_16 (Dense)            (None, 256)               393472
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 64)                16448
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_18 (Dense)            (None, 128)               8320
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 5,466,813
# Trainable params: 5,466,813
# Non-trainable params: 0
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/5!
# Running setup of directory for experiment NumberOfAuthorsNN/5
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 160s 187ms/step - loss: 1.1030 - accuracy: 0.5828 - val_loss: 0.6425 - val_accuracy: 0.7634 - time: 159.5546
# Epoch 2/10
# 847/847 [==============================] - 157s 186ms/step - loss: 0.4995 - accuracy: 0.8264 - val_loss: 0.5104 - val_accuracy: 0.8232 - time: 316.8859
# Epoch 3/10
# 847/847 [==============================] - 147s 173ms/step - loss: 0.3091 - accuracy: 0.8965 - val_loss: 0.5174 - val_accuracy: 0.8306 - time: 463.5582
# Epoch 4/10
# 847/847 [==============================] - 135s 160ms/step - loss: 0.2031 - accuracy: 0.9327 - val_loss: 0.5587 - val_accuracy: 0.8350 - time: 599.0874
# Epoch 5/10
# 847/847 [==============================] - 130s 153ms/step - loss: 0.1520 - accuracy: 0.9506 - val_loss: 0.6258 - val_accuracy: 0.8327 - time: 728.7462
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_5 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_5 (Embedding)     (None, 130, 50)           750000
#
#  conv1d_15 (Conv1D)          (None, 127, 128)          25728
#
#  max_pooling1d_15 (MaxPoolin  (None, 63, 128)          0
#  g1D)
#
#  conv1d_16 (Conv1D)          (None, 58, 256)           196864
#
#  max_pooling1d_16 (MaxPoolin  (None, 29, 256)          0
#  g1D)
#
#  conv1d_17 (Conv1D)          (None, 24, 128)           196736
#
#  max_pooling1d_17 (MaxPoolin  (None, 12, 128)          0
#  g1D)
#
#  flatten_5 (Flatten)         (None, 1536)              0
#
#  dense_20 (Dense)            (None, 256)               393472
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 64)                16448
#
#  dropout_16 (Dropout)        (None, 64)                0
#
#  dense_22 (Dense)            (None, 128)               8320
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 1,588,213
# Trainable params: 838,213
# Non-trainable params: 750,000
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/6!
# Running setup of directory for experiment NumberOfAuthorsNN/6
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 84s 97ms/step - loss: 1.6101 - accuracy: 0.2956 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 83.9453
# Epoch 2/10
# 847/847 [==============================] - 89s 105ms/step - loss: 1.6096 - accuracy: 0.2001 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 173.3345
# Epoch 3/10
# 847/847 [==============================] - 93s 109ms/step - loss: 1.6096 - accuracy: 0.2012 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 318.6008
# Epoch 4/10
# 847/847 [==============================] - 94s 111ms/step - loss: 1.6095 - accuracy: 0.2006 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 412.3716
# Epoch 5/10
# 847/847 [==============================] - 93s 110ms/step - loss: 1.6095 - accuracy: 0.2012 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 505.3790
# Epoch 6/10
# 847/847 [==============================] - 95s 112ms/step - loss: 1.6095 - accuracy: 0.2010 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 600.0231
# Epoch 7/10
# 847/847 [==============================] - 91s 107ms/step - loss: 1.6095 - accuracy: 0.2010 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 691.0671
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_6 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_6 (Embedding)     (None, 130, 150)          2250000
#
#  conv1d_18 (Conv1D)          (None, 127, 128)          76928
#
#  max_pooling1d_18 (MaxPoolin  (None, 63, 128)          0
#  g1D)
#
#  conv1d_19 (Conv1D)          (None, 58, 256)           196864
#
#  max_pooling1d_19 (MaxPoolin  (None, 29, 256)          0
#  g1D)
#
#  conv1d_20 (Conv1D)          (None, 24, 128)           196736
#
#  max_pooling1d_20 (MaxPoolin  (None, 12, 128)          0
#  g1D)
#
#  flatten_6 (Flatten)         (None, 1536)              0
#
#  dense_24 (Dense)            (None, 256)               393472
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 64)                16448
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 128)               8320
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_27 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,139,413
# Trainable params: 889,413
# Non-trainable params: 2,250,000
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/7!
# Running setup of directory for experiment NumberOfAuthorsNN/7
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 111s 129ms/step - loss: 1.6100 - accuracy: 0.1989 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 110.4594
# Epoch 2/10
# 847/847 [==============================] - 111s 131ms/step - loss: 1.6096 - accuracy: 0.1982 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 221.5835
# Epoch 3/10
# 847/847 [==============================] - 112s 132ms/step - loss: 1.6095 - accuracy: 0.2000 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 333.2391
# Epoch 4/10
# 847/847 [==============================] - 112s 132ms/step - loss: 1.6095 - accuracy: 0.2008 - val_loss: 1.6096 - val_accuracy: 0.1937 - time: 445.3048
# Epoch 5/10
# 847/847 [==============================] - 111s 131ms/step - loss: 1.6095 - accuracy: 0.2001 - val_loss: 1.6097 - val_accuracy: 0.1937 - time: 555.8389
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_7 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_7 (Embedding)     (None, 130, 300)          4500000
#
#  conv1d_21 (Conv1D)          (None, 127, 128)          153728
#
#  max_pooling1d_21 (MaxPoolin  (None, 63, 128)          0
#  g1D)
#
#  conv1d_22 (Conv1D)          (None, 58, 256)           196864
#  max_pooling1d_22 (MaxPoolin  (None, 29, 256)          0
#  g1D)
#
#  conv1d_23 (Conv1D)          (None, 24, 128)           196736
#
#  max_pooling1d_23 (MaxPoolin  (None, 12, 128)          0
#  g1D)
#
#  flatten_7 (Flatten)         (None, 1536)              0
#
#  dense_28 (Dense)            (None, 256)               393472
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 64)                16448
#
#  dropout_22 (Dropout)        (None, 64)                0
#
#  dense_30 (Dense)            (None, 128)               8320
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_31 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 5,466,213
# Trainable params: 966,213
# Non-trainable params: 4,500,000
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/8!
# Running setup of directory for experiment NumberOfAuthorsNN/8
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 126s 146ms/step - loss: 1.6100 - accuracy: 0.1984 - val_loss: 1.6095 - val_accuracy: 0.1956 - time: 126.1441
# Epoch 2/10
# 847/847 [==============================] - 127s 150ms/step - loss: 1.6096 - accuracy: 0.1983 - val_loss: 1.6095 - val_accuracy: 0.1956 - time: 253.4510
# Epoch 3/10
# 847/847 [==============================] - 126s 149ms/step - loss: 1.6082 - accuracy: 0.2044 - val_loss: 1.5282 - val_accuracy: 0.3094 - time: 379.5267
# Epoch 4/10
# 847/847 [==============================] - 157s 186ms/step - loss: 1.3211 - accuracy: 0.4358 - val_loss: 1.1685 - val_accuracy: 0.5018 - time: 536.6531
# Epoch 5/10
# 847/847 [==============================] - 124s 147ms/step - loss: 1.0773 - accuracy: 0.5522 - val_loss: 1.0755 - val_accuracy: 0.5584 - time: 660.9323
# Epoch 6/10
# 847/847 [==============================] - 120s 142ms/step - loss: 0.8817 - accuracy: 0.6483 - val_loss: 1.0609 - val_accuracy: 0.5827 - time: 781.0934
# Epoch 7/10
# 847/847 [==============================] - 122s 144ms/step - loss: 0.7343 - accuracy: 0.7157 - val_loss: 1.1130 - val_accuracy: 0.5971 - time: 903.0510
# Epoch 8/10
# 847/847 [==============================] - 126s 148ms/step - loss: 0.6400 - accuracy: 0.7594 - val_loss: 1.2025 - val_accuracy: 0.5969 - time: 1028.6729
# Epoch 9/10
# 847/847 [==============================] - 124s 147ms/step - loss: 0.5563 - accuracy: 0.7952 - val_loss: 1.2259 - val_accuracy: 0.6065 - time: 1153.0252
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 1)]               0
#
#  text_vectorization_8 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_8 (Embedding)     (None, 130, 300)          4500600
#
#  conv1d_24 (Conv1D)          (None, 127, 128)          153728
#
#  max_pooling1d_24 (MaxPoolin  (None, 63, 128)          0
#  g1D)
#
#  conv1d_25 (Conv1D)          (None, 58, 256)           196864
#
#  max_pooling1d_25 (MaxPoolin  (None, 29, 256)          0
#  g1D)
#
#  conv1d_26 (Conv1D)          (None, 24, 128)           196736
#
#  max_pooling1d_26 (MaxPoolin  (None, 12, 128)          0
#  g1D)
#
#  flatten_8 (Flatten)         (None, 1536)              0
#
#  dense_32 (Dense)            (None, 256)               393472
#
#  dropout_24 (Dropout)        (None, 256)               0
#
#  dense_33 (Dense)            (None, 64)                16448
#
#  dropout_25 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 128)               8320
#
#  dropout_26 (Dropout)        (None, 128)               0
#
#  dense_35 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 5,466,813
# Trainable params: 966,213
# Non-trainable params: 4,500,600
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/9!
# Running setup of directory for experiment NumberOfAuthorsNN/9
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 130s 151ms/step - loss: 1.5274 - accuracy: 0.3397 - val_loss: 1.3228 - val_accuracy: 0.4267 - time: 129.6540
# Epoch 2/10
# 847/847 [==============================] - 124s 147ms/step - loss: 1.1182 - accuracy: 0.5619 - val_loss: 0.9334 - val_accuracy: 0.6660 - time: 268.1646
# Epoch 3/10
# 847/847 [==============================] - 124s 146ms/step - loss: 0.8182 - accuracy: 0.7064 - val_loss: 0.8005 - val_accuracy: 0.7080 - time: 391.8064
# Epoch 4/10
# 847/847 [==============================] - 122s 144ms/step - loss: 0.6365 - accuracy: 0.7783 - val_loss: 0.8066 - val_accuracy: 0.7113 - time: 514.0096
# Epoch 5/10
# 847/847 [==============================] - 132s 155ms/step - loss: 0.5228 - accuracy: 0.8213 - val_loss: 0.7906 - val_accuracy: 0.7226 - time: 645.5720
# Epoch 6/10
# 847/847 [==============================] - 110s 130ms/step - loss: 0.4339 - accuracy: 0.8547 - val_loss: 0.9615 - val_accuracy: 0.6778 - time: 755.9773
# Epoch 7/10
# 847/847 [==============================] - 102s 120ms/step - loss: 0.3714 - accuracy: 0.8771 - val_loss: 0.8771 - val_accuracy: 0.7117 - time: 857.9000
# Epoch 8/10
# 847/847 [==============================] - 100s 118ms/step - loss: 0.3167 - accuracy: 0.8957 - val_loss: 0.9385 - val_accuracy: 0.7211 - time: 957.9408
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_9 (TextV  (None, 130)              0
#  ectorization)
#
#  embedding_9 (Embedding)     (None, 130, 300)          4500600
#
#  conv1d_27 (Conv1D)          (None, 127, 128)          153728
#
#  max_pooling1d_27 (MaxPoolin  (None, 63, 128)          0
#  g1D)
#
#  conv1d_28 (Conv1D)          (None, 58, 256)           196864
#
#  max_pooling1d_28 (MaxPoolin  (None, 29, 256)          0
#  g1D)
#
#  conv1d_29 (Conv1D)          (None, 24, 128)           196736
#
#  max_pooling1d_29 (MaxPoolin  (None, 12, 128)          0
#  g1D)
#
#  flatten_9 (Flatten)         (None, 1536)              0
#
#  dense_36 (Dense)            (None, 256)               393472
#
#  dropout_27 (Dropout)        (None, 256)               0
#
#  dense_37 (Dense)            (None, 64)                16448
#
#  dropout_28 (Dropout)        (None, 64)                0
#
#  dense_38 (Dense)            (None, 128)               8320
#
#  dropout_29 (Dropout)        (None, 128)               0
#
#  dense_39 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 5,466,813
# Trainable params: 966,213
# Non-trainable params: 4,500,600
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/10!
# Running setup of directory for experiment NumberOfAuthorsNN/10
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 119s 137ms/step - loss: 1.5734 - accuracy: 0.3137 - val_loss: 1.3710 - val_accuracy: 0.4072 - time: 118.6584
# Epoch 2/10
# 847/847 [==============================] - 124s 146ms/step - loss: 1.2166 - accuracy: 0.4969 - val_loss: 1.1081 - val_accuracy: 0.5455 - time: 242.3810
# Epoch 3/10
# 847/847 [==============================] - 124s 146ms/step - loss: 1.0091 - accuracy: 0.5979 - val_loss: 1.0094 - val_accuracy: 0.5967 - time: 366.1756
# Epoch 4/10
# 847/847 [==============================] - 120s 142ms/step - loss: 0.8420 - accuracy: 0.6768 - val_loss: 0.9795 - val_accuracy: 0.6261 - time: 486.0895
# Epoch 5/10
# 847/847 [==============================] - 124s 146ms/step - loss: 0.6889 - accuracy: 0.7490 - val_loss: 0.9714 - val_accuracy: 0.6289 - time: 610.0498
# Epoch 6/10
# 847/847 [==============================] - 128s 151ms/step - loss: 0.5728 - accuracy: 0.7972 - val_loss: 0.9973 - val_accuracy: 0.6588 - time: 737.9176
# Epoch 7/10
# 847/847 [==============================] - 125s 148ms/step - loss: 0.4806 - accuracy: 0.8330 - val_loss: 1.1476 - val_accuracy: 0.6408 - time: 863.0412
# Epoch 8/10
# 847/847 [==============================] - 125s 148ms/step - loss: 0.4174 - accuracy: 0.8589 - val_loss: 1.1600 - val_accuracy: 0.6714 - time: 988.3020
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "RNNBidirectionalLSTMAndGru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_10 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_10 (Embedding)    (None, 130, 50)           750000
#
#  bidirectional (Bidirectiona  (None, 130, 128)         58880
#  l)
#
#  gru (GRU)                   (None, 64)                37248
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dropout_30 (Dropout)        (None, 64)                0
#
#  dense_40 (Dense)            (None, 32)                2080
#
#  dropout_31 (Dropout)        (None, 32)                0
#
#  dense_41 (Dense)            (None, 64)                2112
#
# ...
# Epoch 2/10
# 847/847 [==============================] - 891s 1s/step - loss: 1.3135 - accuracy: 0.4060 - val_loss: nan - val_accuracy: 0.1937 - time: 1962.9866
# Epoch 3/10
# 847/847 [==============================] - 1059s 1s/step - loss: 1.5695 - accuracy: 0.2694 - val_loss: nan - val_accuracy: 0.1937 - time: 3022.0102
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "RNNBidirectionalLSTMAndGru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_13 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_13 (Embedding)    (None, 130, 300)          4500600
#
#  bidirectional_3 (Bidirectio  (None, 130, 128)         186880
#  nal)
#
#  gru_3 (GRU)                 (None, 64)                37248
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_36 (Dropout)        (None, 64)                0
#
#  dense_49 (Dense)            (None, 32)                2080
#
#  dropout_37 (Dropout)        (None, 32)                0
#
#  dense_50 (Dense)            (None, 64)                2112
#
#  dense_51 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 4,729,501
# Trainable params: 4,729,373
# Non-trainable params: 128
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/14!
# Running setup of directory for experiment NumberOfAuthorsNN/14
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 971s 1s/step - loss: 1.6041 - accuracy: 0.2295 - val_loss: 2.1056 - val_accuracy: 0.2225 - time: 971.2478
# Epoch 2/10
# 847/847 [==============================] - 1006s 1s/step - loss: 1.5744 - accuracy: 0.2707 - val_loss: 3.3657 - val_accuracy: 0.2003 - time: 1977.3829
# Epoch 3/10
# 847/847 [==============================] - 1043s 1s/step - loss: 1.5461 - accuracy: 0.2899 - val_loss: 7.4510 - val_accuracy: 0.2114 - time: 3020.5195
# Epoch 4/10
# 847/847 [==============================] - 1017s 1s/step - loss: 1.4990 - accuracy: 0.3256 - val_loss: 142.7331 - val_accuracy: 0.1956 - time: 4037.1013
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "RNNBidirectionalLSTMAndGru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_14 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_14 (Embedding)    (None, 130, 300)          4500600
#
#  bidirectional_4 (Bidirectio  (None, 130, 128)         186880
#  nal)
#
#  gru_4 (GRU)                 (None, 64)                37248
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_38 (Dropout)        (None, 64)                0
#
#  dense_52 (Dense)            (None, 32)                2080
#
#  dropout_39 (Dropout)        (None, 32)                0
#
#  dense_53 (Dense)            (None, 64)                2112
#
#  dense_54 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 4,729,501
# Trainable params: 4,729,373
# Non-trainable params: 128
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/15!
# Running setup of directory for experiment NumberOfAuthorsNN/15
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 1054s 1s/step - loss: 1.5982 - accuracy: 0.2202 - val_loss: nan - val_accuracy: 0.1937 - time: 1053.6387
# Epoch 2/10
# 847/847 [==============================] - 1051s 1s/step - loss: 1.2598 - accuracy: 0.4371 - val_loss: nan - val_accuracy: 0.1937 - time: 2104.6184
# Epoch 3/10
# 847/847 [==============================] - 1057s 1s/step - loss: 1.0521 - accuracy: 0.5553 - val_loss: nan - val_accuracy: 0.1937 - time: 3161.1459
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "RNNBidirectionalLSTMAndGru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_15 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_15 (Embedding)    (None, 130, 50)           750000
#
#  bidirectional_5 (Bidirectio  (None, 130, 128)         58880
#  nal)
#
#  gru_5 (GRU)                 (None, 64)                37248
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_40 (Dropout)        (None, 64)                0
#
#  dense_55 (Dense)            (None, 32)                2080
#
#  dropout_41 (Dropout)        (None, 32)                0
#
#  dense_56 (Dense)            (None, 64)                2112
#
#  dense_57 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 850,901
# Trainable params: 100,773
# Non-trainable params: 750,128
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/16!
# Running setup of directory for experiment NumberOfAuthorsNN/16
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 1041s 1s/step - loss: 1.6049 - accuracy: 0.2110 - val_loss: 1.6729 - val_accuracy: 0.2047 - time: 1040.6028
# Epoch 2/10
# 847/847 [==============================] - 885s 1s/step - loss: 1.5457 - accuracy: 0.2841 - val_loss: nan - val_accuracy: 0.1937 - time: 1926.2557
# Epoch 3/10
# 847/847 [==============================] - 933s 1s/step - loss: 1.4640 - accuracy: 0.3405 - val_loss: nan - val_accuracy: 0.1937 - time: 2858.9310
# Epoch 4/10
# 847/847 [==============================] - 1023s 1s/step - loss: 1.3960 - accuracy: 0.3889 - val_loss: nan - val_accuracy: 0.1937 - time: 3882.2833
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "RNNBidirectionalLSTMAndGru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_16 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_16 (Embedding)    (None, 130, 150)          2250000
#
#  bidirectional_6 (Bidirectio  (None, 130, 128)         110080
#  nal)
#
#  gru_6 (GRU)                 (None, 64)                37248
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_42 (Dropout)        (None, 64)                0
#
#  dense_58 (Dense)            (None, 32)                2080
#
#  dropout_43 (Dropout)        (None, 32)                0
#
#  dense_59 (Dense)            (None, 64)                2112
#
#  dense_60 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 2,402,101
# Trainable params: 151,973
# Non-trainable params: 2,250,128
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/17!
# Running setup of directory for experiment NumberOfAuthorsNN/17
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - 1015s 1s/step - loss: nan - accuracy: 0.2008 - val_loss: nan - val_accuracy: 0.1937 - time: 1014.5702
# Epoch 2/10
# 847/847 [==============================] - 991s 1s/step - loss: nan - accuracy: 0.2018 - val_loss: nan - val_accuracy: 0.1937 - time: 2006.1184
# Epoch 3/10
# 847/847 [==============================] - 981s 1s/step - loss: nan - accuracy: 0.2018 - val_loss: nan - val_accuracy: 0.1937 - time: 2987.2102
# Predicting test dataset
# Evaluating results
# Mapping timer
# End of maping timer
# Saving
# Saving results
# Saving decription of experiment
# End of experiment
# Settings =
#  BatchSize=64Epochs=10LearningRate=0.001Metric=SparseCategoricalAccuracy(name=accuracy,dtype=float32)Loss=<keras.losses.SparseCategoricalCrossentropy object at 0x7fc1bc047040>Optimizer=<keras.optimizer_v2.adam.Adam object at 0x7fbefa599820>
# Model: "RNNBidirectionalLSTMAndGru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 1)]               0
#
#  text_vectorization_17 (Text  (None, 130)              0
#  Vectorization)
#
#  embedding_17 (Embedding)    (None, 130, 300)          4500000
#
#  bidirectional_7 (Bidirectio  (None, 130, 128)         186880
#  nal)
#
#  gru_7 (GRU)                 (None, 64)                37248
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_44 (Dropout)        (None, 64)                0
#
#  dense_61 (Dense)            (None, 32)                2080
#
#  dropout_45 (Dropout)        (None, 32)                0
#
#  dense_62 (Dense)            (None, 64)                2112
#
#  dense_63 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 4,728,901
# Trainable params: 228,773
# Non-trainable params: 4,500,128
# _________________________________________________________________
# Creating new experiment summarization for NumberOfAuthorsNN/18!
# Running setup of directory for experiment NumberOfAuthorsNN/18
# Compiling model
# Fitting model
# Epoch 1/10
# 847/847 [==============================] - ETA: 0s - loss: 1.6002 - accuracy: 0.2213
